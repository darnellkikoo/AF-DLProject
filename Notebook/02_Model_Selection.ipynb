# %% [markdown]
# # Importing Data

# %%
import os
import gc
import re
import cv2
import sys
import glob
from glob import glob
import tensorflow as tf
import keras

import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style  as style

from tqdm  import tqdm
from keras import backend
from sklearn.metrics     import accuracy_score, roc_auc_score
from keras.layers        import Dense, Dropout, Flatten, BatchNormalization, GlobalMaxPooling2D
from keras.models        import Sequential, Model, load_model
from keras.callbacks     import ModelCheckpoint,ReduceLROnPlateau, CSVLogger
from keras.activations   import elu
from keras.engine        import Layer, InputSpec
from keras.applications  import MobileNetV2
from keras.optimizers    import Adam
from keras.preprocessing import image
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator
# from keras.applications.mobilenetv2 import preprocess_input, decode_predictions

# %%
# Compose filenames
filelist_mt = glob('../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/*.png')
filelist_shenzen     = glob('../input/pulmonary-chest-xray-abnormalities/ChinaSet_AllFiles/ChinaSet_AllFiles/CXR_png/*.png')
filelist             = filelist_mt + filelist_shenzen

# %%
j = 0
for i in filelist:
    print(i)
    if j == 5:
        break
    j+=1
# Out:
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0017_0.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0020_0.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0030_0.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0013_0.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0354_1.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0044_0.png

# %%
def extract_label(file_list):
    '''
    Label Extraction Function
    Reads a filename and extracts label from it
    '''
    labels = []
    for file in tqdm(file_list):
        current_label = re.findall('[0-9]{4}_(.+?).png', file)
#         print(current_label)
        labels.append(current_label[0])
    return(labels)

# %%
label = extract_label(filelist)
# Out:
# 100%|██████████| 800/800 [00:00<00:00, 172631.74it/s]

# %%
len(label)
# Out:
# 800

# %%
df = pd.DataFrame(filelist, columns = ['Path'])
df['Label'] = label

y = df['Label']
X = df.drop(['Label'], axis = 1)
X.shape, y.shape
# Out:
# ((800, 1), (800,))

# %% [markdown]
# # Splitting Data
#
# We will first split the data into 80% for Training and 20% for Testing
# Then, we will split the Training data (again) for 80% Training and 20% Validation.
#
# It is important to divide the data into 3 parts, so that we can have data for both testing (unseen data) and validation

# %%
#80% Training 20% Testing
df_train, X_test, label_train, y_test = train_test_split(X,
                                                         y,
                                                         stratify = y,
                                                         random_state = 19,
                                                         test_size = 0.2)

# %%
# 80% Training 20% Validation
X_train, X_valid, y_train, y_valid = train_test_split(df_train,
                                                     label_train,
                                                     stratify = label_train,
                                                     random_state = 19,
                                                     test_size = 0.2)

# %%
print('Train size')
print(X_train.shape, y_train.shape)
print('Validation Size')
print(X_valid.shape, y_valid.shape)
print('Testing Size')
print(X_test.shape, y_test.shape)
# Out:
# Train size
# (512, 1) (512,)
# Validation Size
# (128, 1) (128,)
# Testing Size
# (160, 1) (160,)

# %% [markdown]
# For easier dataframe usage, we will make them into each dataframe

# %%
# Train
train_df = X_train.copy()
train_df['Label'] = y_train


#Valid
valid_df = X_valid.copy()
valid_df['Label'] = y_valid


#Test
test_df = X_test.copy()
test_df['Label'] = y_test

# %%
train_df.head()
# Out:
#                                                   Path Label
# 761  ../input/pulmonary-chest-xray-abnormalities/Ch...     1
# 577  ../input/pulmonary-chest-xray-abnormalities/Ch...     1
# 484  ../input/pulmonary-chest-xray-abnormalities/Ch...     0
# 299  ../input/pulmonary-chest-xray-abnormalities/Ch...     0
# 99   ../input/pulmonary-chest-xray-abnormalities/Mo...     1

# %% [raw]
# train_df.head()

# %% [markdown]
# # Exploratory Data Analysis

# %%
print("Train Value Counts")
print(train_df['Label'].value_counts())
print("Validation DF Value Counts")
print(valid_df['Label'].value_counts())
print("Test DF Value Counts")
print(test_df['Label'].value_counts())
# Out:
# Train Value Counts
# 0    260
# 1    252
# Name: Label, dtype: int64
# Validation DF Value Counts
# 0    65
# 1    63
# Name: Label, dtype: int64
# Test DF Value Counts
# 0    81
# 1    79
# Name: Label, dtype: int64

# %% [markdown]
# The label seems to be well distributed, so we will use accuracy, ROC, and Recall as our main metrics. We would want to prevent any wrong prediction of people with Pneumonia. Hence, Recall metric is important

# %%
def plot_multiple_images(image_dataframe, rows = 4, columns = 4, figsize = (16, 20), resize=(1024,1024), preprocessing=None):
    '''
    Plots Multiple Images
    Reads, resizes, applies preprocessing if desired and plots multiple images from a given dataframe
    '''
    image_dataframe = image_dataframe.reset_index(drop=True)
    fig, ax = plt.subplots(rows, columns, figsize=figsize)
#     print(image_dataframe)
    i = 1
    for j in range(rows):
        for k in range(columns):
            img = plt.imread(image_dataframe.loc[i-1,'Path'])
            img = cv2.resize(img, resize)
            if preprocessing:
                img = preprocessing(img)
            ax[j][k].set_title("Xray "+str(i))
            a = image_dataframe.loc[i-1, 'Label']
            if int(a) == 0:
                ax[j][k].set_xlabel('Normal')
            else:
                ax[j][k].set_xlabel('Pneumonia')  
                
            ax[j][k].imshow(img, alpha=1, cmap='gray')
            i+=1
            
        if(i == (rows*columns)):
            break
    plt.show()

# %%
plot_multiple_images(train_df)

# %%
train_df.head()
# Out:
#                                                   Path Label
# 761  ../input/pulmonary-chest-xray-abnormalities/Ch...     1
# 577  ../input/pulmonary-chest-xray-abnormalities/Ch...     1
# 484  ../input/pulmonary-chest-xray-abnormalities/Ch...     0
# 299  ../input/pulmonary-chest-xray-abnormalities/Ch...     0
# 99   ../input/pulmonary-chest-xray-abnormalities/Mo...     1

# %% [markdown]
# # Baseline Model

# %% [markdown]
# Making a baseline model is important to have a benchmark model, so that we can know how our new model improve each time we train it. We will use a batch size of 32, and image size of 224x224

# %%
BATCH = 32
IMAGE_INPUT = (224, 224)

# %% [markdown]
# We will use ImageDataGenerator from Keras, which functions to load some image (based on our BATCH size that we set) at a time.
# Here we will only scale the image /255, so that it is between 0 and 255, because we only want to train our baseline model.

# %%
#Creating Training Data Generator
tf.random.set_seed(19)
train_generator = ImageDataGenerator(rescale = 1./255,)

# Create Validation data generator
test_generator  = ImageDataGenerator(rescale = 1./255,)

# %%
train = train_generator.flow_from_dataframe(dataframe = train_df,
                                    class_mode  = 'binary',
                                    x_col       = 'Path',
                                    y_col       = 'Label',
                                    shuffle     = True,
                                    batch_size  = BATCH,
                                    target_size = IMAGE_INPUT,
                                    seed=19)

valid = train_generator.flow_from_dataframe(dataframe = valid_df,
                                    class_mode  = 'binary',
                                    x_col       = 'Path',
                                    y_col       = 'Label',
                                    shuffle     = True,
                                    batch_size  = BATCH,
                                    target_size = IMAGE_INPUT,
                                    seed=19)
# Out:
# Found 512 validated image filenames belonging to 2 classes.
# Found 128 validated image filenames belonging to 2 classes.

# %%
test = test_generator.flow_from_dataframe(dataframe = test_df,
                                    class_mode  = 'binary',
                                    x_col       = 'Path',
                                    y_col       = 'Label',
                                    shuffle     = False,
                                    batch_size  = BATCH,
                                    target_size = IMAGE_INPUT)
# Out:
# Found 160 validated image filenames belonging to 2 classes.

# %% [markdown]
# This shows that there will be 512 data for training and 128 data for validation, each having 2 classes, normal and with pneumonia

# %% [markdown]
# ## Creating the baseline model
#
# Now we can create the baseline cnn model

# %%
metrics=['accuracy','Precision', keras.metrics.Recall(), keras.metrics.AUC()]

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)
baselineM = Sequential([
  keras.layers.Conv2D(filters=10, 
                      kernel_size=3, 
                      strides=1,
                      padding='valid',
                      activation='relu', 
         input_shape=(224, 224, 3)), # input layer (specify input shape)
  keras.layers.Conv2D(10, 3, activation='relu'),
  keras.layers.Conv2D(10, 3, activation='relu'),
  keras.layers.Flatten(),
  Dense(1, activation='sigmoid') # output layer (specify output shape)
])

baselineM.compile(loss='binary_crossentropy',
                optimizer=Adam(learning_rate = 5e-4),
                metrics=[metrics])

baselineM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 10)      280
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 10)      910
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 218, 218, 10)      910
# _________________________________________________________________
# flatten (Flatten)            (None, 475240)            0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 475241
# =================================================================
# Total params: 477,341
# Trainable params: 477,341
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We also need to set a callback, to help us in getting better accuracy with efficient time usage.

# %%
# %load_ext tensorboard

# %%
#Tensorflow Callback
# %load_ext tensorboard
logdir = os.path.join("logs", "BaselineModel")
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("baseline_model.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# We can now finally train our model

# %%
baseHistory = baselineM.fit(
            train,
            callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()],
            epochs    = 20,
            steps_per_epoch  = len(train),
            validation_data  = valid,
            validation_steps = len(valid))

baselineM = keras.models.load_model('baseline_model.h5')
# Out:
# Epoch 1/20
# 16/16 [==============================] - 146s 9s/step - loss: 2.0034 - accuracy: 0.4959 - precision: 0.4644 - recall: 0.5498 - auc: 0.4888 - val_loss: 0.6135 - val_accuracy: 0.6641 - val_precision: 0.6220 - val_recall: 0.8095 - val_auc: 0.7999
# val / train : 0.41
# Epoch 2/20
# 16/16 [==============================] - 70s 4s/step - loss: 0.6854 - accuracy: 0.5613 - precision: 0.5530 - recall: 0.8281 - auc: 0.6463 - val_loss: 0.6668 - val_accuracy: 0.5078 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8212
# val / train : 0.98
# Epoch 3/20
# 16/16 [==============================] - 69s 4s/step - loss: 0.6425 - accuracy: 0.6109 - precision: 0.8826 - recall: 0.2482 - auc: 0.8479 - val_loss: 0.5695 - val_accuracy: 0.8203 - val_precision: 0.8448 - val_recall: 0.7778 - val_auc: 0.8812
# val / train : 0.91
# Epoch 4/20
# 16/16 [==============================] - 70s 4s/step - loss: 0.5227 - accuracy: 0.8179 - precision: 0.8712 - recall: 0.7153 - auc: 0.8722 - val_loss: 0.4514 - val_accuracy: 0.8438 - val_precision: 0.8525 - val_recall: 0.8254 - val_auc: 0.8845
# val / train : 0.86
# Epoch 5/20
# 16/16 [==============================] - 70s 4s/step - loss: 0.4229 - accuracy: 0.8180 - precision: 0.8694 - recall: 0.7505 - auc: 0.9037 - val_loss: 0.3955 - val_accuracy: 0.8594 - val_precision: 0.9091 - val_recall: 0.7937 - val_auc: 0.9043
# val / train : 0.90
# Epoch 6/20
# 16/16 [==============================] - 70s 4s/step - loss: 0.3937 - accuracy: 0.8455 - precision: 0.8953 - recall: 0.7668 - auc: 0.9103 - val_loss: 0.3700 - val_accuracy: 0.8438 - val_precision: 0.8644 - val_recall: 0.8095 - val_auc: 0.9160
# val / train : 0.96
# Epoch 7/20
# 16/16 [==============================] - 71s 4s/step - loss: 0.3124 - accuracy: 0.8742 - precision: 0.9253 - recall: 0.8108 - auc: 0.9447 - val_loss: 0.3764 - val_accuracy: 0.8516 - val_precision: 0.8235 - val_recall: 0.8889 - val_auc: 0.9233
# val / train : 1.24
# Epoch 8/20
# 16/16 [==============================] - 70s 4s/step - loss: 0.2530 - accuracy: 0.9015 - precision: 0.9206 - recall: 0.8756 - auc: 0.9674 - val_loss: 0.4197 - val_accuracy: 0.8516 - val_precision: 0.9074 - val_recall: 0.7778 - val_auc: 0.9106
# val / train : 1.71
# Epoch 9/20
# 16/16 [==============================] - 70s 4s/step - loss: 0.2183 - accuracy: 0.9432 - precision: 0.9521 - recall: 0.9258 - auc: 0.9906 - val_loss: 0.4139 - val_accuracy: 0.8438 - val_precision: 0.7867 - val_recall: 0.9365 - val_auc: 0.9204
# val / train : 2.05
# Epoch 10/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.1739 - accuracy: 0.9325 - precision: 0.9221 - recall: 0.9533 - auc: 0.9888 - val_loss: 0.3740 - val_accuracy: 0.8516 - val_precision: 0.8793 - val_recall: 0.8095 - val_auc: 0.9291
# val / train : 2.47
# Epoch 11/20
# 16/16 [==============================] - 70s 4s/step - loss: 0.1239 - accuracy: 0.9808 - precision: 0.9993 - recall: 0.9637 - auc: 0.9975 - val_loss: 0.4218 - val_accuracy: 0.8359 - val_precision: 0.7838 - val_recall: 0.9206 - val_auc: 0.9283
# val / train : 3.72

# %% [markdown]
# We can see that the val/train loss is getting bigger and bigger each time the epoch ends. It can be concluded that this model is overfiting towards the training data

# %%
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-30181032ab6bad4d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-30181032ab6bad4d");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
def plot_training_hist(keras_model):
    '''
    Plot training History
    Creates two plots of model training logs
    '''
    hist = keras_model.history
    style.use('fivethirtyeight')
    
    # Loss Plot
    fig = plt.figure(figsize=(8,3))
    plt.title('Loss Plot')
    plt.plot(hist['loss'], '#07e9ed')
    plt.plot(hist['val_loss'], '#0791ed')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.ylim([0,1.2 * max(max(hist['loss'], hist['val_loss']))])
    plt.legend(['train', 'validation'], loc='lower right')
    plt.show()
    
    # Accuracy Plot
    fig = plt.figure(figsize=(8,3))
    plt.title('Accuracy Plot')
    plt.plot(hist['accuracy'], '#07e9ed')
    plt.plot(hist['val_accuracy'], '#0791ed')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')    
    plt.legend(['train', 'validation'], loc='lower right')
    plt.ylim([0,1])
    
    #ROC Plot
    fig = plt.figure(figsize=(8,3))
    plt.title('AUC Plot')
    plt.plot(hist['auc'], '#07e9ed')
    plt.plot(hist['val_auc'], '#0791ed')
    plt.xlabel('Epochs')
    plt.ylabel('AUC Score')    
    plt.legend(['train', 'validation'], loc='lower right')
    plt.ylim([0,1])
    # Show Plot, reset style
    plt.show()
    style.use('default')

# %%
plot_training_hist(baseHistory)

# %% [markdown]
# It is quite good, but we can still improve it with augmented data. Augmented data has proven to help the model to be less overfit, and become a better one when predicting unseen dataset.

# %% [markdown]
# # Augmented Training Data

# %% [markdown]
# Data augmentation plays a major role in making our data more diverse to prevent overfitting towards our model, especially when our dataset is small enough to be used on real world datasets.

# %%
train_df.shape
# Out:
# (512, 2)

# %% [markdown]
# We will still be using ImageDataGenerator to augment our training data

# %%
train_aug_generator = ImageDataGenerator(rescale = 1./255,
                                     zoom_range      = 0.05,
                                     shear_range     = 0,
                                     width_shift_range  = 0.05,
                                     height_shift_range = 0.05,
                                     )

train_aug = train_aug_generator.flow_from_dataframe(dataframe = train_df,
                                    class_mode  = 'binary',
                                    x_col       = 'Path',
                                    y_col       = 'Label',
                                    shuffle     = True,
                                    batch_size  = BATCH,
                                    target_size = IMAGE_INPUT,
                                    seed=19)
# Out:
# Found 512 validated image filenames belonging to 2 classes.

# %%
#Tensorflow Callback
# %load_ext tensorboard
logdir = os.path.join("logs", "BaselineModel-Augment")
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("baseline_augment.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# Now we can retrain our new model with augmented data

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

baselineM2 = Sequential([
  keras.layers.Conv2D(filters=10, 
                      kernel_size=3, 
                      strides=1,
                      padding='valid',
                      activation='relu', 
         input_shape=(224, 224, 3)), # input layer (specify input shape)
  keras.layers.Conv2D(10, 3, activation='relu'),
  keras.layers.Conv2D(10, 3, activation='relu'),
  keras.layers.Flatten(),
  Dense(1, activation='sigmoid') # output layer (specify output shape)
])

baselineM2.compile(loss='binary_crossentropy',
                optimizer=Adam(learning_rate = 5e-4),
                metrics=[metrics])

baselineM2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 10)      280
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 10)      910
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 218, 218, 10)      910
# _________________________________________________________________
# flatten (Flatten)            (None, 475240)            0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 475241
# =================================================================
# Total params: 477,341
# Trainable params: 477,341
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseHistory2 = baselineM2.fit(
            train_aug,
            callbacks = [callbacks],
            epochs    = 20,
            steps_per_epoch  = len(train),
            validation_data  = valid,
            validation_steps = len(valid))

baselineM2 = keras.models.load_model('baseline_augment.h5')
# Out:
# Epoch 1/20
# 16/16 [==============================] - 79s 5s/step - loss: 1.8603 - accuracy: 0.4736 - precision: 0.4542 - recall: 0.6734 - auc: 0.6367 - val_loss: 0.6642 - val_accuracy: 0.5391 - val_precision: 0.5172 - val_recall: 0.9524 - val_auc: 0.8038
# val / train : 0.45
# Epoch 2/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.6779 - accuracy: 0.5655 - precision: 0.5572 - recall: 0.8506 - auc: 0.6388 - val_loss: 0.6314 - val_accuracy: 0.6016 - val_precision: 0.8000 - val_recall: 0.2540 - val_auc: 0.8225
# val / train : 0.95
# Epoch 3/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.6283 - accuracy: 0.6255 - precision: 0.7174 - recall: 0.3953 - auc: 0.7558 - val_loss: 0.5697 - val_accuracy: 0.7500 - val_precision: 0.8974 - val_recall: 0.5556 - val_auc: 0.8393
# val / train : 0.92
# Epoch 4/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.5778 - accuracy: 0.7280 - precision: 0.7876 - recall: 0.6116 - auc: 0.7854 - val_loss: 0.4995 - val_accuracy: 0.8125 - val_precision: 0.8095 - val_recall: 0.8095 - val_auc: 0.8625
# val / train : 0.88
# Epoch 5/20
# 16/16 [==============================] - 75s 5s/step - loss: 0.5475 - accuracy: 0.7468 - precision: 0.7768 - recall: 0.6556 - auc: 0.8056 - val_loss: 0.4648 - val_accuracy: 0.8281 - val_precision: 0.8868 - val_recall: 0.7460 - val_auc: 0.8729
# val / train : 0.87
# Epoch 6/20
# 16/16 [==============================] - 76s 5s/step - loss: 0.5373 - accuracy: 0.7480 - precision: 0.7753 - recall: 0.7006 - auc: 0.8152 - val_loss: 0.5342 - val_accuracy: 0.7188 - val_precision: 0.6484 - val_recall: 0.9365 - val_auc: 0.8808
# val / train : 0.99
# Epoch 7/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.5217 - accuracy: 0.7655 - precision: 0.7657 - recall: 0.7641 - auc: 0.8235 - val_loss: 0.4392 - val_accuracy: 0.8125 - val_precision: 0.8824 - val_recall: 0.7143 - val_auc: 0.8857
# val / train : 0.83
# Epoch 8/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.5118 - accuracy: 0.7566 - precision: 0.7814 - recall: 0.7278 - auc: 0.8363 - val_loss: 0.4854 - val_accuracy: 0.7656 - val_precision: 0.6897 - val_recall: 0.9524 - val_auc: 0.9023
# val / train : 0.93
# Epoch 9/20
# 16/16 [==============================] - 75s 5s/step - loss: 0.4985 - accuracy: 0.7458 - precision: 0.7162 - recall: 0.8259 - auc: 0.8555 - val_loss: 0.4548 - val_accuracy: 0.7812 - val_precision: 0.7108 - val_recall: 0.9365 - val_auc: 0.8996
# val / train : 0.91
# Epoch 10/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.5149 - accuracy: 0.7662 - precision: 0.7739 - recall: 0.7485 - auc: 0.8246 - val_loss: 0.4043 - val_accuracy: 0.8203 - val_precision: 0.8333 - val_recall: 0.7937 - val_auc: 0.9116
# val / train : 0.78
# Epoch 11/20
# 16/16 [==============================] - 75s 5s/step - loss: 0.5269 - accuracy: 0.7302 - precision: 0.7336 - recall: 0.7248 - auc: 0.8207 - val_loss: 0.4485 - val_accuracy: 0.7812 - val_precision: 0.7059 - val_recall: 0.9524 - val_auc: 0.9151
# val / train : 0.86
# Epoch 12/20
# 16/16 [==============================] - 75s 5s/step - loss: 0.4936 - accuracy: 0.7929 - precision: 0.7742 - recall: 0.7947 - auc: 0.8545 - val_loss: 0.4107 - val_accuracy: 0.8281 - val_precision: 0.8596 - val_recall: 0.7778 - val_auc: 0.9182
# val / train : 0.81
# Epoch 13/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.4729 - accuracy: 0.7662 - precision: 0.7850 - recall: 0.7144 - auc: 0.8571 - val_loss: 0.3868 - val_accuracy: 0.8281 - val_precision: 0.8868 - val_recall: 0.7460 - val_auc: 0.9172
# val / train : 0.84
# Epoch 14/20
# 16/16 [==============================] - 76s 5s/step - loss: 0.4616 - accuracy: 0.7920 - precision: 0.8201 - recall: 0.7639 - auc: 0.8698 - val_loss: 0.4060 - val_accuracy: 0.8203 - val_precision: 0.8571 - val_recall: 0.7619 - val_auc: 0.9122
# val / train : 0.85
# Epoch 15/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.4798 - accuracy: 0.7774 - precision: 0.7761 - recall: 0.7274 - auc: 0.8496 - val_loss: 0.4421 - val_accuracy: 0.8047 - val_precision: 0.7375 - val_recall: 0.9365 - val_auc: 0.9066
# val / train : 0.95
# Epoch 16/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4611 - accuracy: 0.7656 - precision: 0.7526 - recall: 0.7588 - auc: 0.8633 - val_loss: 0.4028 - val_accuracy: 0.8047 - val_precision: 0.7639 - val_recall: 0.8730 - val_auc: 0.9111
# val / train : 0.91
# Epoch 17/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4944 - accuracy: 0.7636 - precision: 0.7456 - recall: 0.7361 - auc: 0.8424 - val_loss: 0.4212 - val_accuracy: 0.8281 - val_precision: 0.8254 - val_recall: 0.8254 - val_auc: 0.8989
# val / train : 0.85
# Epoch 18/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.4810 - accuracy: 0.7773 - precision: 0.8260 - recall: 0.6732 - auc: 0.8621 - val_loss: 0.4227 - val_accuracy: 0.8203 - val_precision: 0.7703 - val_recall: 0.9048 - val_auc: 0.9151
# val / train : 0.86

# %%
plot_training_hist(baseHistory2)

# %% [markdown]
# It is way better than the previous overfit model! So we will use this augmented dataset for other training too. From previous training, lowering the learning rate didn't give any major improvement. Hence, we will move on to the pretrained model

# %%
baselineM2.evaluate(valid)
# Out:
# 4/4 [==============================] - 14s 4s/step - loss: 0.4227 - accuracy: 0.8203 - precision: 0.7703 - recall: 0.9048 - auc: 0.9151
# [0.42270761728286743,
#  0.8203125,
#  0.7702702879905701,
#  0.9047619104385376,
#  0.9151403307914734]

# %% [markdown]
# # Use Pretrained Model

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers

# %% [markdown]
# We will now use a pretrained model tu achieve a better result

# %%
def create_model(model_url, num_classes=10):
  """Takes a TensorFlow Hub URL and creates a Keras Sequential model with it.
  
  Args:
    model_url (str): A TensorFlow Hub feature extraction URL.
    num_classes (int): Number of output neurons in output layer,
      should be equal to number of target classes, default 10.

  Returns:
    An uncompiled Keras Sequential model with model_url as feature
    extractor layer and Dense output layer with num_classes outputs.
  """
  # Download the pretrained model and save it as a Keras layer
  feature_extractor_layer = hub.KerasLayer(model_url,
                                           trainable=False, # freeze the underlying patterns
                                           name='feature_extraction_layer',
                                           input_shape=IMAGE_INPUT+(3,)) # define the input image shape
  
  # Create our own model
  model = tf.keras.Sequential([
    feature_extractor_layer, # use the feature extraction layer as the base
    layers.Dense(num_classes, activation='sigmoid', name='output_layer') # create our own output layer      
  ])

  return model

# %% [markdown]
# ## ResNet50

# %% [markdown]
# Resnet50 URL

# %%
resnet50_url = 'https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/5'

# %%
#Tensorflow Callback
# %load_ext tensorboard
logdir = os.path.join("logs", "resnet50")
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("resnet_model.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

resnet_model = create_model(resnet50_url, 1)

# Compile
resnet_model.compile(loss='binary_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(learning_rate = 5e-4),
                     metrics=[metrics])

# %%
resnet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature_extraction_layer (Ke (None, 2048)              23564800
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 2049
# =================================================================
# Total params: 23,566,849
# Trainable params: 2,049
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
resnet_history = resnet_model.fit(
            train_aug,
            callbacks = [callbacks],
            epochs    = 20,
            steps_per_epoch  = len(train),
            validation_data  = valid,
            validation_steps = len(valid))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 82s 5s/step - loss: 0.7282 - accuracy: 0.5444 - precision: 0.5547 - recall: 0.6597 - auc: 0.7089 - val_loss: 0.6659 - val_accuracy: 0.5703 - val_precision: 0.5833 - val_recall: 0.4444 - val_auc: 0.6272
# val / train : 0.94
# Epoch 2/20
# 16/16 [==============================] - 75s 5s/step - loss: 0.6610 - accuracy: 0.6050 - precision: 0.6221 - recall: 0.5361 - auc: 0.6600 - val_loss: 0.5920 - val_accuracy: 0.6641 - val_precision: 0.6389 - val_recall: 0.7302 - val_auc: 0.7521
# val / train : 0.93
# Epoch 3/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.6094 - accuracy: 0.6820 - precision: 0.6660 - recall: 0.6808 - auc: 0.7345 - val_loss: 0.5566 - val_accuracy: 0.6953 - val_precision: 0.6500 - val_recall: 0.8254 - val_auc: 0.8045
# val / train : 0.94
# Epoch 4/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5534 - accuracy: 0.7365 - precision: 0.7428 - recall: 0.7622 - auc: 0.8057 - val_loss: 0.5155 - val_accuracy: 0.7344 - val_precision: 0.7231 - val_recall: 0.7460 - val_auc: 0.8413
# val / train : 0.95
# Epoch 5/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5679 - accuracy: 0.7300 - precision: 0.7667 - recall: 0.6859 - auc: 0.7886 - val_loss: 0.4915 - val_accuracy: 0.7734 - val_precision: 0.7931 - val_recall: 0.7302 - val_auc: 0.8629
# val / train : 0.90
# Epoch 6/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5445 - accuracy: 0.7266 - precision: 0.7989 - recall: 0.6325 - auc: 0.8185 - val_loss: 0.4726 - val_accuracy: 0.7969 - val_precision: 0.7846 - val_recall: 0.8095 - val_auc: 0.8711
# val / train : 0.91
# Epoch 7/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4890 - accuracy: 0.7685 - precision: 0.8003 - recall: 0.6933 - auc: 0.8600 - val_loss: 0.4725 - val_accuracy: 0.7734 - val_precision: 0.7179 - val_recall: 0.8889 - val_auc: 0.8799
# val / train : 0.95
# Epoch 8/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4960 - accuracy: 0.7670 - precision: 0.7492 - recall: 0.7513 - auc: 0.8554 - val_loss: 0.4535 - val_accuracy: 0.7734 - val_precision: 0.7297 - val_recall: 0.8571 - val_auc: 0.8868
# val / train : 0.91
# Epoch 9/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4914 - accuracy: 0.7855 - precision: 0.7893 - recall: 0.7960 - auc: 0.8535 - val_loss: 0.4363 - val_accuracy: 0.8125 - val_precision: 0.8095 - val_recall: 0.8095 - val_auc: 0.8912
# val / train : 0.92
# Epoch 10/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4716 - accuracy: 0.7851 - precision: 0.8410 - recall: 0.7058 - auc: 0.8727 - val_loss: 0.4291 - val_accuracy: 0.8047 - val_precision: 0.7794 - val_recall: 0.8413 - val_auc: 0.8965
# val / train : 0.95
# Epoch 11/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.4350 - accuracy: 0.8136 - precision: 0.7943 - recall: 0.8020 - auc: 0.8963 - val_loss: 0.4246 - val_accuracy: 0.8047 - val_precision: 0.7714 - val_recall: 0.8571 - val_auc: 0.8995
# val / train : 0.93
# Epoch 12/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4223 - accuracy: 0.8143 - precision: 0.7773 - recall: 0.8564 - auc: 0.9096 - val_loss: 0.4164 - val_accuracy: 0.8047 - val_precision: 0.7969 - val_recall: 0.8095 - val_auc: 0.8993
# val / train : 0.93
# Epoch 13/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4496 - accuracy: 0.7961 - precision: 0.7870 - recall: 0.8071 - auc: 0.8785 - val_loss: 0.4147 - val_accuracy: 0.7891 - val_precision: 0.7500 - val_recall: 0.8571 - val_auc: 0.9042
# val / train : 0.91
# Epoch 14/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4163 - accuracy: 0.8342 - precision: 0.8689 - recall: 0.7928 - auc: 0.9042 - val_loss: 0.4001 - val_accuracy: 0.8359 - val_precision: 0.8387 - val_recall: 0.8254 - val_auc: 0.9092
# val / train : 0.91
# Epoch 15/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4323 - accuracy: 0.8247 - precision: 0.8637 - recall: 0.7773 - auc: 0.8943 - val_loss: 0.3995 - val_accuracy: 0.8125 - val_precision: 0.7826 - val_recall: 0.8571 - val_auc: 0.9106
# val / train : 0.95
# Epoch 16/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4639 - accuracy: 0.7959 - precision: 0.8226 - recall: 0.7523 - auc: 0.8657 - val_loss: 0.3941 - val_accuracy: 0.8203 - val_precision: 0.8030 - val_recall: 0.8413 - val_auc: 0.9125
# val / train : 0.92
# Epoch 17/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4165 - accuracy: 0.8121 - precision: 0.8439 - recall: 0.7537 - auc: 0.8981 - val_loss: 0.3978 - val_accuracy: 0.8047 - val_precision: 0.7639 - val_recall: 0.8730 - val_auc: 0.9137
# val / train : 0.96
# Epoch 18/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4171 - accuracy: 0.8107 - precision: 0.8180 - recall: 0.7966 - auc: 0.8965 - val_loss: 0.3828 - val_accuracy: 0.8438 - val_precision: 0.8413 - val_recall: 0.8413 - val_auc: 0.9167
# val / train : 0.94
# Epoch 19/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4149 - accuracy: 0.8086 - precision: 0.8209 - recall: 0.7862 - auc: 0.8978 - val_loss: 0.3932 - val_accuracy: 0.8047 - val_precision: 0.7568 - val_recall: 0.8889 - val_auc: 0.9166
# val / train : 0.91
# Epoch 20/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4245 - accuracy: 0.8054 - precision: 0.8009 - recall: 0.8046 - auc: 0.8906 - val_loss: 0.3817 - val_accuracy: 0.8594 - val_precision: 0.8571 - val_recall: 0.8571 - val_auc: 0.9164
# val / train : 0.93

# %%
# resnet_model = keras.models.load_model('resnet_model.h5')

# %%
plot_training_hist(resnet_history)

# %%
resnet_model.evaluate(valid)
# Out:
# 4/4 [==============================] - 14s 3s/step - loss: 0.3817 - accuracy: 0.8594 - precision: 0.8571 - recall: 0.8571 - auc: 0.9164
# [0.3817235827445984,
#  0.859375,
#  0.8571428656578064,
#  0.8571428656578064,
#  0.9163614511489868]

# %% [markdown]
# It has a big improvement in both the Loss and Val_Loss, accuracy and also auc! we can now train with other model to look for the best architecture

# %% [markdown]
# ## ResNet 152

# %%
Resnet152_url = 'https://tfhub.dev/google/imagenet/resnet_v2_152/feature_vector/5'

# %%
# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("resnet152_model.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

resnet152 = create_model(Resnet152_url, 1)

# Compile
resnet152.compile(loss='binary_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(learning_rate = 5e-4),
                     metrics=[metrics])

# %%
resnet152.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature_extraction_layer (Ke (None, 2048)              58331648
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 2049
# =================================================================
# Total params: 58,333,697
# Trainable params: 2,049
# Non-trainable params: 58,331,648
# _________________________________________________________________

# %%
resnet152_history = resnet152.fit(
                  train_aug,
                  callbacks = [callbacks],
                  epochs    = 20,
                  steps_per_epoch  = len(train),
                  validation_data  = valid,
                  validation_steps = len(valid))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 89s 5s/step - loss: 0.6822 - accuracy: 0.5867 - precision: 0.5829 - recall: 0.7412 - auc: 0.7677 - val_loss: 0.6045 - val_accuracy: 0.6641 - val_precision: 0.6667 - val_recall: 0.6349 - val_auc: 0.7410
# val / train : 0.92
# Epoch 2/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.6048 - accuracy: 0.6846 - precision: 0.6736 - recall: 0.7051 - auc: 0.7441 - val_loss: 0.5598 - val_accuracy: 0.7188 - val_precision: 0.7455 - val_recall: 0.6508 - val_auc: 0.7996
# val / train : 0.94
# Epoch 3/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5563 - accuracy: 0.7460 - precision: 0.7685 - recall: 0.6715 - auc: 0.8034 - val_loss: 0.5248 - val_accuracy: 0.7344 - val_precision: 0.6933 - val_recall: 0.8254 - val_auc: 0.8349
# val / train : 0.94
# Epoch 4/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5460 - accuracy: 0.7150 - precision: 0.7293 - recall: 0.7053 - auc: 0.8073 - val_loss: 0.5019 - val_accuracy: 0.7969 - val_precision: 0.8136 - val_recall: 0.7619 - val_auc: 0.8508
# val / train : 0.93
# Epoch 5/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.5051 - accuracy: 0.7723 - precision: 0.7845 - recall: 0.7537 - auc: 0.8550 - val_loss: 0.4836 - val_accuracy: 0.8047 - val_precision: 0.7879 - val_recall: 0.8254 - val_auc: 0.8621
# val / train : 0.93
# Epoch 6/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5173 - accuracy: 0.7548 - precision: 0.7862 - recall: 0.6787 - auc: 0.8360 - val_loss: 0.4741 - val_accuracy: 0.7422 - val_precision: 0.7027 - val_recall: 0.8254 - val_auc: 0.8768
# val / train : 0.95
# Epoch 7/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5020 - accuracy: 0.7769 - precision: 0.7622 - recall: 0.7722 - auc: 0.8422 - val_loss: 0.4571 - val_accuracy: 0.8047 - val_precision: 0.7969 - val_recall: 0.8095 - val_auc: 0.8775
# val / train : 0.95
# Epoch 8/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4973 - accuracy: 0.7682 - precision: 0.8048 - recall: 0.7035 - auc: 0.8434 - val_loss: 0.4510 - val_accuracy: 0.7812 - val_precision: 0.7536 - val_recall: 0.8254 - val_auc: 0.8832
# val / train : 0.94
# Epoch 9/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4558 - accuracy: 0.8180 - precision: 0.8257 - recall: 0.8075 - auc: 0.8864 - val_loss: 0.4402 - val_accuracy: 0.8047 - val_precision: 0.8065 - val_recall: 0.7937 - val_auc: 0.8857
# val / train : 0.95
# Epoch 10/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4468 - accuracy: 0.8128 - precision: 0.8087 - recall: 0.8028 - auc: 0.8850 - val_loss: 0.4355 - val_accuracy: 0.7812 - val_precision: 0.7612 - val_recall: 0.8095 - val_auc: 0.8875
# val / train : 1.00
# Epoch 11/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.4791 - accuracy: 0.7853 - precision: 0.8040 - recall: 0.7682 - auc: 0.8604 - val_loss: 0.4371 - val_accuracy: 0.8125 - val_precision: 0.8305 - val_recall: 0.7778 - val_auc: 0.8860
# val / train : 0.97
# Epoch 12/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4485 - accuracy: 0.8279 - precision: 0.8814 - recall: 0.7552 - auc: 0.8940 - val_loss: 0.4248 - val_accuracy: 0.8047 - val_precision: 0.7969 - val_recall: 0.8095 - val_auc: 0.8924
# val / train : 0.99
# Epoch 13/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4533 - accuracy: 0.8343 - precision: 0.8773 - recall: 0.7731 - auc: 0.8757 - val_loss: 0.4206 - val_accuracy: 0.8047 - val_precision: 0.7969 - val_recall: 0.8095 - val_auc: 0.8940
# val / train : 0.96
# Epoch 14/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.3855 - accuracy: 0.8489 - precision: 0.8487 - recall: 0.8542 - auc: 0.9178 - val_loss: 0.4161 - val_accuracy: 0.8047 - val_precision: 0.8065 - val_recall: 0.7937 - val_auc: 0.8971
# val / train : 0.98
# Epoch 15/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4019 - accuracy: 0.8575 - precision: 0.8787 - recall: 0.8252 - auc: 0.9120 - val_loss: 0.4117 - val_accuracy: 0.8047 - val_precision: 0.7879 - val_recall: 0.8254 - val_auc: 0.9007
# val / train : 0.98
# Epoch 16/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4163 - accuracy: 0.8419 - precision: 0.8421 - recall: 0.8462 - auc: 0.9012 - val_loss: 0.4111 - val_accuracy: 0.8047 - val_precision: 0.8065 - val_recall: 0.7937 - val_auc: 0.8976
# val / train : 1.00
# Epoch 17/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4076 - accuracy: 0.8562 - precision: 0.8808 - recall: 0.7925 - auc: 0.9016 - val_loss: 0.4084 - val_accuracy: 0.8203 - val_precision: 0.8030 - val_recall: 0.8413 - val_auc: 0.8989
# val / train : 1.02
# Epoch 18/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.3916 - accuracy: 0.8629 - precision: 0.8680 - recall: 0.8544 - auc: 0.9151 - val_loss: 0.4105 - val_accuracy: 0.8125 - val_precision: 0.8197 - val_recall: 0.7937 - val_auc: 0.8965
# val / train : 1.01
# Epoch 19/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.3997 - accuracy: 0.8380 - precision: 0.8836 - recall: 0.7760 - auc: 0.9089 - val_loss: 0.4014 - val_accuracy: 0.8125 - val_precision: 0.8000 - val_recall: 0.8254 - val_auc: 0.9015
# val / train : 1.00
# Epoch 20/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.3717 - accuracy: 0.8466 - precision: 0.8821 - recall: 0.8006 - auc: 0.9259 - val_loss: 0.3995 - val_accuracy: 0.8047 - val_precision: 0.8065 - val_recall: 0.7937 - val_auc: 0.9011
# val / train : 1.02

# %%
plot_training_hist(resnet152_history)

# %%
resnet152.evaluate(valid)
# Out:
# 4/4 [==============================] - 16s 4s/step - loss: 0.3995 - accuracy: 0.8047 - precision: 0.8065 - recall: 0.7937 - auc: 0.9011
# [0.3994916081428528,
#  0.8046875,
#  0.8064516186714172,
#  0.7936508059501648,
#  0.901098906993866]

# %% [markdown]
# ## EfficientNet

# %% [markdown]
# EfficientNet is know to have a better and faster model training compared to ResNet, so we will try to use it in our next modelling

# %% [markdown]
# ### EfficientNet B0

# %%
EFFB0_url = 'https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1'

# %%
#Tensorflow Callback
# %load_ext tensorboard
logdir = os.path.join("logs", "efficientb0")
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("efficientb0_model.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

efficientb0 = create_model(EFFB0_url, 1)

# Compile
efficientb0.compile(loss='binary_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(learning_rate = 5e-4),
                     metrics=[metrics])

# %%
efficientb0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature_extraction_layer (Ke (None, 1280)              4049564
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 1281
# =================================================================
# Total params: 4,050,845
# Trainable params: 1,281
# Non-trainable params: 4,049,564
# _________________________________________________________________

# %%
efficientb0_history = efficientb0.fit(
            train_aug,
            callbacks = [callbacks],
            epochs    = 20,
            steps_per_epoch  = len(train),
            validation_data  = valid,
            validation_steps = len(valid))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 90s 5s/step - loss: 0.6875 - accuracy: 0.5706 - precision: 0.5785 - recall: 0.4594 - auc: 0.7354 - val_loss: 0.6403 - val_accuracy: 0.6641 - val_precision: 0.6351 - val_recall: 0.7460 - val_auc: 0.7424
# val / train : 0.95
# Epoch 2/20
# 16/16 [==============================] - 75s 5s/step - loss: 0.6429 - accuracy: 0.6615 - precision: 0.6490 - recall: 0.7697 - auc: 0.7136 - val_loss: 0.5996 - val_accuracy: 0.7422 - val_precision: 0.9167 - val_recall: 0.5238 - val_auc: 0.8364
# val / train : 0.95
# Epoch 3/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.6099 - accuracy: 0.7503 - precision: 0.8828 - recall: 0.6135 - auc: 0.7837 - val_loss: 0.5611 - val_accuracy: 0.8203 - val_precision: 0.9348 - val_recall: 0.6825 - val_auc: 0.8703
# val / train : 0.94
# Epoch 4/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.5762 - accuracy: 0.7577 - precision: 0.8220 - recall: 0.6487 - auc: 0.8015 - val_loss: 0.5378 - val_accuracy: 0.8438 - val_precision: 0.9574 - val_recall: 0.7143 - val_auc: 0.8858
# val / train : 0.95
# Epoch 5/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5594 - accuracy: 0.7639 - precision: 0.8049 - recall: 0.6387 - auc: 0.8074 - val_loss: 0.5177 - val_accuracy: 0.8047 - val_precision: 0.8654 - val_recall: 0.7143 - val_auc: 0.8928
# val / train : 0.93
# Epoch 6/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5407 - accuracy: 0.7954 - precision: 0.7958 - recall: 0.7580 - auc: 0.8341 - val_loss: 0.5008 - val_accuracy: 0.8125 - val_precision: 0.8545 - val_recall: 0.7460 - val_auc: 0.8943
# val / train : 0.94
# Epoch 7/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.5031 - accuracy: 0.8272 - precision: 0.8759 - recall: 0.7583 - auc: 0.8664 - val_loss: 0.4843 - val_accuracy: 0.8359 - val_precision: 0.8889 - val_recall: 0.7619 - val_auc: 0.9002
# val / train : 0.93
# Epoch 8/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5210 - accuracy: 0.7818 - precision: 0.8139 - recall: 0.7103 - auc: 0.8312 - val_loss: 0.4772 - val_accuracy: 0.8516 - val_precision: 0.9583 - val_recall: 0.7302 - val_auc: 0.9040
# val / train : 0.92
# Epoch 9/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4941 - accuracy: 0.8084 - precision: 0.8635 - recall: 0.7501 - auc: 0.8679 - val_loss: 0.4688 - val_accuracy: 0.8594 - val_precision: 0.9245 - val_recall: 0.7778 - val_auc: 0.9037
# val / train : 0.97
# Epoch 10/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4959 - accuracy: 0.7776 - precision: 0.7995 - recall: 0.7090 - auc: 0.8543 - val_loss: 0.4573 - val_accuracy: 0.8359 - val_precision: 0.8750 - val_recall: 0.7778 - val_auc: 0.9055
# val / train : 0.92
# Epoch 11/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.5003 - accuracy: 0.7544 - precision: 0.7939 - recall: 0.6866 - auc: 0.8467 - val_loss: 0.4512 - val_accuracy: 0.8516 - val_precision: 0.8929 - val_recall: 0.7937 - val_auc: 0.9060
# val / train : 0.93
# Epoch 12/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4704 - accuracy: 0.8182 - precision: 0.8695 - recall: 0.7518 - auc: 0.8705 - val_loss: 0.4466 - val_accuracy: 0.8516 - val_precision: 0.9400 - val_recall: 0.7460 - val_auc: 0.9077
# val / train : 0.93
# Epoch 13/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.4434 - accuracy: 0.8264 - precision: 0.8543 - recall: 0.7849 - auc: 0.8998 - val_loss: 0.4417 - val_accuracy: 0.8516 - val_precision: 0.8793 - val_recall: 0.8095 - val_auc: 0.9051
# val / train : 0.93
# Epoch 14/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4644 - accuracy: 0.8076 - precision: 0.8373 - recall: 0.7594 - auc: 0.8752 - val_loss: 0.4432 - val_accuracy: 0.8438 - val_precision: 0.9216 - val_recall: 0.7460 - val_auc: 0.9040
# val / train : 0.95
# Epoch 15/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4733 - accuracy: 0.7953 - precision: 0.8349 - recall: 0.7003 - auc: 0.8583 - val_loss: 0.4375 - val_accuracy: 0.8516 - val_precision: 0.8929 - val_recall: 0.7937 - val_auc: 0.9054
# val / train : 0.93
# Epoch 16/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4775 - accuracy: 0.8031 - precision: 0.8038 - recall: 0.7625 - auc: 0.8569 - val_loss: 0.4371 - val_accuracy: 0.8516 - val_precision: 0.8929 - val_recall: 0.7937 - val_auc: 0.9044
# val / train : 0.96
# Epoch 17/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4609 - accuracy: 0.7973 - precision: 0.8225 - recall: 0.7459 - auc: 0.8704 - val_loss: 0.4359 - val_accuracy: 0.8438 - val_precision: 0.8909 - val_recall: 0.7778 - val_auc: 0.9037
# val / train : 0.97
# Epoch 18/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4401 - accuracy: 0.8125 - precision: 0.8550 - recall: 0.7656 - auc: 0.8901 - val_loss: 0.4309 - val_accuracy: 0.8516 - val_precision: 0.9074 - val_recall: 0.7778 - val_auc: 0.9049
# val / train : 0.97
# Epoch 19/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4455 - accuracy: 0.8282 - precision: 0.8708 - recall: 0.7624 - auc: 0.8839 - val_loss: 0.4308 - val_accuracy: 0.8438 - val_precision: 0.8909 - val_recall: 0.7778 - val_auc: 0.9032
# val / train : 0.98
# Epoch 20/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4630 - accuracy: 0.8074 - precision: 0.8335 - recall: 0.7730 - auc: 0.8698 - val_loss: 0.4281 - val_accuracy: 0.8438 - val_precision: 0.8909 - val_recall: 0.7778 - val_auc: 0.9029
# val / train : 0.96

# %%
# efficientb0 = keras.models.load_model('efficientb0_model.h5')

# %%
plot_training_hist(efficientb0_history)

# %%
efficientb0.evaluate(valid)
# Out:
# 4/4 [==============================] - 14s 4s/step - loss: 0.4281 - accuracy: 0.8438 - precision: 0.8909 - recall: 0.7778 - auc: 0.9029
# [0.42809242010116577,
#  0.84375,
#  0.8909090757369995,
#  0.7777777910232544,
#  0.9029304385185242]

# %% [markdown]
# ### EfficientNet B1

# %%
EFFB1_url = 'https://tfhub.dev/tensorflow/efficientnet/b1/feature-vector/1'

# %%
#Tensorflow Callback
# %load_ext tensorboard
logdir = os.path.join("logs", "efficientb1")
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("efficientb1_model.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

efficientb1 = create_model(EFFB1_url, 1)

# Compile
efficientb1.compile(loss='binary_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(learning_rate = 5e-4),
                     metrics=[metrics])

# %%
efficientb1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature_extraction_layer (Ke (None, 1280)              6575232
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 1281
# =================================================================
# Total params: 6,576,513
# Trainable params: 1,281
# Non-trainable params: 6,575,232
# _________________________________________________________________

# %% [markdown]
# The params for the efficientnet-b1 is 1/3 of the resnet50, and known to have a better result. It is really worth to try with less time computation, who knows that we can get a better result in accuracy, loss and auc.

# %%
efficient_history = efficientb1.fit(
            train_aug,
            callbacks = [callbacks],
            epochs    = 20,
            steps_per_epoch  = len(train),
            validation_data  = valid,
            validation_steps = len(valid))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 92s 5s/step - loss: 0.6861 - accuracy: 0.5655 - precision: 0.5462 - recall: 0.6058 - auc: 0.7278 - val_loss: 0.6401 - val_accuracy: 0.7109 - val_precision: 0.6912 - val_recall: 0.7460 - val_auc: 0.7274
# val / train : 0.94
# Epoch 2/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.6532 - accuracy: 0.6097 - precision: 0.6041 - recall: 0.6852 - auc: 0.6664 - val_loss: 0.5948 - val_accuracy: 0.7500 - val_precision: 0.8039 - val_recall: 0.6508 - val_auc: 0.8154
# val / train : 0.93
# Epoch 3/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.6180 - accuracy: 0.6848 - precision: 0.6822 - recall: 0.5949 - auc: 0.7437 - val_loss: 0.5561 - val_accuracy: 0.8047 - val_precision: 0.8393 - val_recall: 0.7460 - val_auc: 0.8578
# val / train : 0.91
# Epoch 4/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5923 - accuracy: 0.7015 - precision: 0.6945 - recall: 0.6812 - auc: 0.7882 - val_loss: 0.5313 - val_accuracy: 0.8125 - val_precision: 0.8305 - val_recall: 0.7778 - val_auc: 0.8718
# val / train : 0.91
# Epoch 5/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5804 - accuracy: 0.7360 - precision: 0.7554 - recall: 0.7442 - auc: 0.7964 - val_loss: 0.5119 - val_accuracy: 0.8125 - val_precision: 0.8545 - val_recall: 0.7460 - val_auc: 0.8811
# val / train : 0.88
# Epoch 6/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5727 - accuracy: 0.7289 - precision: 0.7717 - recall: 0.6700 - auc: 0.7997 - val_loss: 0.4975 - val_accuracy: 0.8203 - val_precision: 0.8448 - val_recall: 0.7778 - val_auc: 0.8878
# val / train : 0.91
# Epoch 7/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5351 - accuracy: 0.7875 - precision: 0.7987 - recall: 0.7546 - auc: 0.8510 - val_loss: 0.4825 - val_accuracy: 0.8047 - val_precision: 0.8393 - val_recall: 0.7460 - val_auc: 0.8937
# val / train : 0.90
# Epoch 8/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5249 - accuracy: 0.7699 - precision: 0.7779 - recall: 0.6917 - auc: 0.8508 - val_loss: 0.4714 - val_accuracy: 0.7969 - val_precision: 0.8033 - val_recall: 0.7778 - val_auc: 0.8969
# val / train : 0.90
# Epoch 9/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5210 - accuracy: 0.7698 - precision: 0.7670 - recall: 0.7572 - auc: 0.8394 - val_loss: 0.4601 - val_accuracy: 0.8125 - val_precision: 0.8421 - val_recall: 0.7619 - val_auc: 0.8985
# val / train : 0.89
# Epoch 10/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5131 - accuracy: 0.7806 - precision: 0.7995 - recall: 0.7592 - auc: 0.8516 - val_loss: 0.4535 - val_accuracy: 0.8047 - val_precision: 0.8167 - val_recall: 0.7778 - val_auc: 0.8996
# val / train : 0.91
# Epoch 11/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5121 - accuracy: 0.7804 - precision: 0.7923 - recall: 0.7156 - auc: 0.8447 - val_loss: 0.4484 - val_accuracy: 0.8125 - val_precision: 0.8000 - val_recall: 0.8254 - val_auc: 0.9022
# val / train : 0.88
# Epoch 12/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5025 - accuracy: 0.7950 - precision: 0.8048 - recall: 0.7498 - auc: 0.8579 - val_loss: 0.4381 - val_accuracy: 0.8125 - val_precision: 0.8305 - val_recall: 0.7778 - val_auc: 0.9044
# val / train : 0.88
# Epoch 13/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4975 - accuracy: 0.7829 - precision: 0.7958 - recall: 0.7579 - auc: 0.8589 - val_loss: 0.4339 - val_accuracy: 0.8125 - val_precision: 0.8095 - val_recall: 0.8095 - val_auc: 0.9066
# val / train : 0.89
# Epoch 14/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4621 - accuracy: 0.8089 - precision: 0.7961 - recall: 0.8122 - auc: 0.8915 - val_loss: 0.4294 - val_accuracy: 0.8047 - val_precision: 0.8065 - val_recall: 0.7937 - val_auc: 0.9070
# val / train : 0.88
# Epoch 15/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4807 - accuracy: 0.7822 - precision: 0.7739 - recall: 0.7775 - auc: 0.8663 - val_loss: 0.4266 - val_accuracy: 0.8047 - val_precision: 0.7969 - val_recall: 0.8095 - val_auc: 0.9084
# val / train : 0.90
# Epoch 16/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4750 - accuracy: 0.8118 - precision: 0.8084 - recall: 0.8175 - auc: 0.8736 - val_loss: 0.4215 - val_accuracy: 0.8203 - val_precision: 0.8333 - val_recall: 0.7937 - val_auc: 0.9096
# val / train : 0.90
# Epoch 17/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4443 - accuracy: 0.8393 - precision: 0.8669 - recall: 0.8065 - auc: 0.8994 - val_loss: 0.4179 - val_accuracy: 0.8203 - val_precision: 0.8333 - val_recall: 0.7937 - val_auc: 0.9100
# val / train : 0.90
# Epoch 18/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4465 - accuracy: 0.8325 - precision: 0.8373 - recall: 0.8153 - auc: 0.8929 - val_loss: 0.4164 - val_accuracy: 0.8125 - val_precision: 0.8095 - val_recall: 0.8095 - val_auc: 0.9107
# val / train : 0.90
# Epoch 19/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.4367 - accuracy: 0.8380 - precision: 0.8308 - recall: 0.8229 - auc: 0.9000 - val_loss: 0.4144 - val_accuracy: 0.8125 - val_precision: 0.8095 - val_recall: 0.8095 - val_auc: 0.9109
# val / train : 0.92
# Epoch 20/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.4230 - accuracy: 0.8516 - precision: 0.8577 - recall: 0.8456 - auc: 0.9064 - val_loss: 0.4113 - val_accuracy: 0.8203 - val_precision: 0.8226 - val_recall: 0.8095 - val_auc: 0.9122
# val / train : 0.89

# %%
# efficientb1 = keras.models.load_model('efficientb1_model.h5')

# %%
plot_training_hist(efficient_history)

# %%
efficientb1.evaluate(valid)
# Out:
# 4/4 [==============================] - 14s 4s/step - loss: 0.4113 - accuracy: 0.8203 - precision: 0.8226 - recall: 0.8095 - auc: 0.9122
# [0.41132989525794983,
#  0.8203125,
#  0.8225806355476379,
#  0.8095238208770752,
#  0.9122099876403809]

# %% [markdown]
# ## DenseNet

# %%
#Tensorflow Callback
# %load_ext tensorboard
logdir = os.path.join("logs", "densenet121")
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("densenet121.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)
from keras import layers

base_model = tf.keras.applications.densenet.DenseNet121(weights='imagenet', include_top = False)
base_model.trainable = False

inputs = layers.Input(shape=(224, 224, 3), name='input_layer')
out = base_model(inputs, training=False)
out = layers.GlobalMaxPooling2D()(out)
out = layers.Dense(1, activation='sigmoid', name='output_layer')(out)
model_dense = keras.Model(inputs, out)

model_dense.compile(optimizer = keras.optimizers.Adam(learning_rate = 5e-4), loss = 'binary_crossentropy', metrics = [metrics])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step

# %%
model_dense.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 224, 224, 3)]     0
# _________________________________________________________________
# densenet121 (Functional)     (None, None, None, 1024)  7037504
# _________________________________________________________________
# global_max_pooling2d (Global (None, 1024)              0
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 1025
# =================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# _________________________________________________________________

# %%
dense121_history = model_dense.fit(
            train_aug,
            callbacks = [callbacks],
            epochs    = 20,
            steps_per_epoch  = len(train),
            validation_data  = valid,
            validation_steps = len(valid))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 85s 5s/step - loss: 4.0649 - accuracy: 0.5297 - precision: 0.4978 - recall: 0.3248 - auc: 0.5772 - val_loss: 1.0149 - val_accuracy: 0.5156 - val_precision: 0.5052 - val_recall: 0.7778 - val_auc: 0.5244
# val / train : 0.35
# Epoch 2/20
# 16/16 [==============================] - 72s 5s/step - loss: 1.1847 - accuracy: 0.5318 - precision: 0.5196 - recall: 0.8967 - auc: 0.5277 - val_loss: 0.9139 - val_accuracy: 0.4766 - val_precision: 0.4545 - val_recall: 0.3175 - val_auc: 0.5377
# val / train : 0.76
# Epoch 3/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.9769 - accuracy: 0.5114 - precision: 0.5342 - recall: 0.3056 - auc: 0.5271 - val_loss: 0.8375 - val_accuracy: 0.5078 - val_precision: 0.5000 - val_recall: 0.5556 - val_auc: 0.5711
# val / train : 0.87
# Epoch 4/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.8981 - accuracy: 0.5283 - precision: 0.5260 - recall: 0.5931 - auc: 0.5553 - val_loss: 0.7988 - val_accuracy: 0.5234 - val_precision: 0.5192 - val_recall: 0.4286 - val_auc: 0.5993
# val / train : 0.89
# Epoch 5/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.8971 - accuracy: 0.5087 - precision: 0.5300 - recall: 0.4376 - auc: 0.5326 - val_loss: 0.7427 - val_accuracy: 0.5234 - val_precision: 0.5161 - val_recall: 0.5079 - val_auc: 0.6277
# val / train : 0.88
# Epoch 6/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.8125 - accuracy: 0.5439 - precision: 0.5586 - recall: 0.4958 - auc: 0.5861 - val_loss: 0.7080 - val_accuracy: 0.5938 - val_precision: 0.5873 - val_recall: 0.5873 - val_auc: 0.6646
# val / train : 0.87
# Epoch 7/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.7951 - accuracy: 0.5533 - precision: 0.5385 - recall: 0.5310 - auc: 0.5897 - val_loss: 0.6744 - val_accuracy: 0.6172 - val_precision: 0.6000 - val_recall: 0.6667 - val_auc: 0.7010
# val / train : 0.88
# Epoch 8/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.7424 - accuracy: 0.6002 - precision: 0.6257 - recall: 0.6054 - auc: 0.6555 - val_loss: 0.6633 - val_accuracy: 0.7031 - val_precision: 0.7451 - val_recall: 0.6032 - val_auc: 0.7236
# val / train : 0.90
# Epoch 9/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.7694 - accuracy: 0.5600 - precision: 0.5907 - recall: 0.5529 - auc: 0.6322 - val_loss: 0.6385 - val_accuracy: 0.7422 - val_precision: 0.7885 - val_recall: 0.6508 - val_auc: 0.7448
# val / train : 0.88
# Epoch 10/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.6774 - accuracy: 0.6460 - precision: 0.6523 - recall: 0.5814 - auc: 0.7018 - val_loss: 0.6236 - val_accuracy: 0.6406 - val_precision: 0.6076 - val_recall: 0.7619 - val_auc: 0.7623
# val / train : 0.88
# Epoch 11/20
# 16/16 [==============================] - 71s 4s/step - loss: 0.6407 - accuracy: 0.6903 - precision: 0.6867 - recall: 0.7140 - auc: 0.7354 - val_loss: 0.5951 - val_accuracy: 0.7031 - val_precision: 0.6984 - val_recall: 0.6984 - val_auc: 0.7722
# val / train : 0.91
# Epoch 12/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.6573 - accuracy: 0.6668 - precision: 0.6675 - recall: 0.6930 - auc: 0.7269 - val_loss: 0.5853 - val_accuracy: 0.7656 - val_precision: 0.8113 - val_recall: 0.6825 - val_auc: 0.7851
# val / train : 0.92
# Epoch 13/20
# 16/16 [==============================] - 71s 4s/step - loss: 0.6139 - accuracy: 0.6865 - precision: 0.6948 - recall: 0.6229 - auc: 0.7483 - val_loss: 0.5667 - val_accuracy: 0.7188 - val_precision: 0.7077 - val_recall: 0.7302 - val_auc: 0.7978
# val / train : 0.90
# Epoch 14/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.6269 - accuracy: 0.6871 - precision: 0.6916 - recall: 0.6633 - auc: 0.7598 - val_loss: 0.5700 - val_accuracy: 0.7109 - val_precision: 0.6757 - val_recall: 0.7937 - val_auc: 0.8098
# val / train : 0.92
# Epoch 15/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.6361 - accuracy: 0.6835 - precision: 0.6785 - recall: 0.7377 - auc: 0.7516 - val_loss: 0.5592 - val_accuracy: 0.7578 - val_precision: 0.8333 - val_recall: 0.6349 - val_auc: 0.8126
# val / train : 0.88
# Epoch 16/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5918 - accuracy: 0.7160 - precision: 0.7429 - recall: 0.7117 - auc: 0.7825 - val_loss: 0.5396 - val_accuracy: 0.7812 - val_precision: 0.8302 - val_recall: 0.6984 - val_auc: 0.8211
# val / train : 0.94
# Epoch 17/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5912 - accuracy: 0.6906 - precision: 0.7318 - recall: 0.5937 - auc: 0.7717 - val_loss: 0.5262 - val_accuracy: 0.7422 - val_precision: 0.7419 - val_recall: 0.7302 - val_auc: 0.8281
# val / train : 0.91
# Epoch 18/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5191 - accuracy: 0.7421 - precision: 0.7493 - recall: 0.7163 - auc: 0.8122 - val_loss: 0.5190 - val_accuracy: 0.7656 - val_precision: 0.7895 - val_recall: 0.7143 - val_auc: 0.8326
# val / train : 0.96
# Epoch 19/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5836 - accuracy: 0.7283 - precision: 0.7357 - recall: 0.7141 - auc: 0.7877 - val_loss: 0.5180 - val_accuracy: 0.7812 - val_precision: 0.8302 - val_recall: 0.6984 - val_auc: 0.8371
# val / train : 0.96
# Epoch 20/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5792 - accuracy: 0.7157 - precision: 0.7340 - recall: 0.6522 - auc: 0.7826 - val_loss: 0.5221 - val_accuracy: 0.7578 - val_precision: 0.7105 - val_recall: 0.8571 - val_auc: 0.8419
# val / train : 0.92

# %%
plot_training_hist(dense121_history)

# %%
model_dense.evaluate(valid)
# Out:
# 4/4 [==============================] - 14s 3s/step - loss: 0.5221 - accuracy: 0.7578 - precision: 0.7105 - recall: 0.8571 - auc: 0.8419
# [0.5220533609390259,
#  0.7578125,
#  0.7105262875556946,
#  0.8571428656578064,
#  0.8418803811073303]

# %% [markdown]
# ## Modelling Conclusion
#
# Model
#
# After trying several pretrained models, we get the ResNet50 pretrained model as the most stable, less overfit and good in getting the best scores in specified metrics (accuracy, auc, recall). Hence, we will use this model for further hyperparameter tuning, or adding layers.

# %% [markdown]
# |Model|Loss | Acc | Precision | Recall | AUC |
# |---   |---   |---   |---   |--- |--- |
# |Baseline|0.422|0.820|0.770|0.904|0.915|
# |ResNet50 V2|0.381|0.859|0.8571|0.8571|0.916|
# |ResNet 151 V2|0.399|0.804|0.806|0.793|0.901|
# |EfficientNetB0|0.428|0.843|0.890|0.777|0.902|
# |EfficientNetB1|0.411|0.820|0.822|0.809|0.912|
# |DenseNet121|0.522|0.757|0.7105|0.8571|0.842|

# %% [markdown]
# These table is generated from the previous models when it is programmed to evaluate validation data. ResNet50 V2 outperformed all the other models with the least loss, and highest score in all other metrics.
