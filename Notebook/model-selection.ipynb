# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Importing Data

# %%
import os
import gc
import re
import cv2
import sys
import glob
from glob import glob
import tensorflow as tf
import keras

import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style  as style

from tqdm  import tqdm
from keras import backend
from sklearn.metrics     import accuracy_score, roc_auc_score
from keras.layers        import Dense, Dropout, Flatten, BatchNormalization, GlobalMaxPooling2D
from keras.models        import Sequential, Model, load_model
from keras.callbacks     import ModelCheckpoint,ReduceLROnPlateau, CSVLogger
from keras.activations   import elu
from keras.engine        import Layer, InputSpec
from keras.applications  import MobileNetV2
from keras.optimizers    import Adam
from keras.preprocessing import image
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator
# from keras.applications.mobilenetv2 import preprocess_input, decode_predictions

# %%
# Compose filenames
filelist_mt = glob('../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/*.png')
filelist_shenzen     = glob('../input/pulmonary-chest-xray-abnormalities/ChinaSet_AllFiles/ChinaSet_AllFiles/CXR_png/*.png')
filelist             = filelist_mt + filelist_shenzen

# %%
j = 0
for i in filelist:
    print(i)
    if j == 5:
        break
    j+=1
# Out:
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0017_0.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0020_0.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0030_0.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0013_0.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0354_1.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0044_0.png

# %%
def extract_label(file_list):
    '''
    Label Extraction Function
    Reads a filename and extracts label from it
    '''
    labels = []
    for file in tqdm(file_list):
        current_label = re.findall('[0-9]{4}_(.+?).png', file)
#         print(current_label)
        labels.append(current_label[0])
    return(labels)

# %%
label = extract_label(filelist)
# Out:
# 100%|██████████| 800/800 [00:00<00:00, 157031.22it/s]

# %%
len(label)
# Out:
# 800

# %%
df = pd.DataFrame(filelist, columns = ['Path'])
df['Label'] = label

y = df['Label']
X = df.drop(['Label'], axis = 1)
X.shape, y.shape
# Out:
# ((800, 1), (800,))

# %% [markdown]
# # Splitting Data
#
# We will first split the data into 80% for Training and 20% for Testing
# Then, we will split the Training data (again) for 80% Training and 20% Validation.
#
# It is important to divide the data into 3 parts, so that we can have data for both testing (unseen data) and validation

# %%
#80% Training 20% Testing
df_train, X_test, label_train, y_test = train_test_split(X,
                                                         y,
                                                         stratify = y,
                                                         random_state = 19,
                                                         test_size = 0.2)

# %%
# 80% Training 20% Validation
X_train, X_valid, y_train, y_valid = train_test_split(df_train,
                                                     label_train,
                                                     stratify = label_train,
                                                     random_state = 19,
                                                     test_size = 0.2)

# %%
print('Train size')
print(X_train.shape, y_train.shape)
print('Validation Size')
print(X_valid.shape, y_valid.shape)
print('Testing Size')
print(X_test.shape, y_test.shape)
# Out:
# Train size
# (512, 1) (512,)
# Validation Size
# (128, 1) (128,)
# Testing Size
# (160, 1) (160,)

# %% [markdown]
# For easier dataframe usage, we will make them into each dataframe

# %%
# Train
train_df = X_train.copy()
train_df['Label'] = y_train


#Valid
valid_df = X_valid.copy()
valid_df['Label'] = y_valid


#Test
test_df = X_test.copy()
test_df['Label'] = y_test

# %%
train_df.head()
# Out:
#                                                   Path Label
# 761  ../input/pulmonary-chest-xray-abnormalities/Ch...     1
# 577  ../input/pulmonary-chest-xray-abnormalities/Ch...     1
# 484  ../input/pulmonary-chest-xray-abnormalities/Ch...     0
# 299  ../input/pulmonary-chest-xray-abnormalities/Ch...     0
# 99   ../input/pulmonary-chest-xray-abnormalities/Mo...     1

# %% [raw]
# train_df.head()

# %% [markdown]
# # Exploratory Data Analysis

# %%
print("Train Value Counts")
print(train_df['Label'].value_counts())
print("Validation DF Value Counts")
print(valid_df['Label'].value_counts())
print("Test DF Value Counts")
print(test_df['Label'].value_counts())
# Out:
# Train Value Counts
# 0    260
# 1    252
# Name: Label, dtype: int64
# Validation DF Value Counts
# 0    65
# 1    63
# Name: Label, dtype: int64
# Test DF Value Counts
# 0    81
# 1    79
# Name: Label, dtype: int64

# %% [markdown]
# The label seems to be well distributed, so we will use accuracy, ROC, and Recall as our main metrics. We would want to prevent any wrong prediction of people with Pneumonia. Hence, Recall metric is important

# %%
def plot_multiple_images(image_dataframe, rows = 4, columns = 4, figsize = (16, 20), resize=(1024,1024), preprocessing=None):
    '''
    Plots Multiple Images
    Reads, resizes, applies preprocessing if desired and plots multiple images from a given dataframe
    '''
    image_dataframe = image_dataframe.reset_index(drop=True)
    fig, ax = plt.subplots(rows, columns, figsize=figsize)
#     print(image_dataframe)
    i = 1
    for j in range(rows):
        for k in range(columns):
            img = plt.imread(image_dataframe.loc[i-1,'Path'])
            img = cv2.resize(img, resize)
            if preprocessing:
                img = preprocessing(img)
            ax[j][k].set_title("Xray "+str(i))
            a = image_dataframe.loc[i-1, 'Label']
            if int(a) == 0:
                ax[j][k].set_xlabel('Normal')
            else:
                ax[j][k].set_xlabel('Pneumonia')  
                
            ax[j][k].imshow(img, alpha=1, cmap='gray')
            i+=1
            
        if(i == (rows*columns)):
            break
    plt.show()

# %%
plot_multiple_images(train_df)

# %%
train_df.head()
# Out:
#                                                   Path Label
# 761  ../input/pulmonary-chest-xray-abnormalities/Ch...     1
# 577  ../input/pulmonary-chest-xray-abnormalities/Ch...     1
# 484  ../input/pulmonary-chest-xray-abnormalities/Ch...     0
# 299  ../input/pulmonary-chest-xray-abnormalities/Ch...     0
# 99   ../input/pulmonary-chest-xray-abnormalities/Mo...     1

# %% [markdown]
# # Baseline Model

# %% [markdown]
# Making a baseline model is important to have a benchmark model, so that we can know how our new model improve each time we train it. We will use a batch size of 32, and image size of 224x224

# %%
BATCH = 32
IMAGE_INPUT = (224, 224)

# %% [markdown]
# We will use ImageDataGenerator from Keras, which functions to load some image (based on our BATCH size that we set) at a time.
# Here we will only scale the image /255, so that it is between 0 and 255, because we only want to train our baseline model.

# %%
#Creating Training Data Generator
tf.random.set_seed(19)
train_generator = ImageDataGenerator(rescale = 1./255,)

# Create Validation data generator
test_generator  = ImageDataGenerator(rescale = 1./255,)

# %%
train = train_generator.flow_from_dataframe(dataframe = train_df,
                                    class_mode  = 'binary',
                                    x_col       = 'Path',
                                    y_col       = 'Label',
                                    shuffle     = True,
                                    batch_size  = BATCH,
                                    target_size = IMAGE_INPUT,
                                    seed=19)

valid = train_generator.flow_from_dataframe(dataframe = valid_df,
                                    class_mode  = 'binary',
                                    x_col       = 'Path',
                                    y_col       = 'Label',
                                    shuffle     = True,
                                    batch_size  = BATCH,
                                    target_size = IMAGE_INPUT,
                                    seed=19)
# Out:
# Found 512 validated image filenames belonging to 2 classes.
# Found 128 validated image filenames belonging to 2 classes.

# %%
test = test_generator.flow_from_dataframe(dataframe = test_df,
                                    class_mode  = 'binary',
                                    x_col       = 'Path',
                                    y_col       = 'Label',
                                    shuffle     = False,
                                    batch_size  = BATCH,
                                    target_size = IMAGE_INPUT)
# Out:
# Found 160 validated image filenames belonging to 2 classes.

# %% [markdown]
# This shows that there will be 512 data for training and 128 data for validation, each having 2 classes, normal and with pneumonia

# %% [markdown]
# ## Creating the baseline model
#
# Now we can create the baseline cnn model

# %%
metrics=['accuracy','Precision', keras.metrics.Recall(), keras.metrics.AUC()]

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)
baselineM = Sequential([
  keras.layers.Conv2D(filters=10, 
                      kernel_size=3, 
                      strides=1,
                      padding='valid',
                      activation='relu', 
         input_shape=(224, 224, 3)), # input layer (specify input shape)
  keras.layers.Conv2D(10, 3, activation='relu'),
  keras.layers.Conv2D(10, 3, activation='relu'),
  keras.layers.Flatten(),
  Dense(1, activation='sigmoid') # output layer (specify output shape)
])

baselineM.compile(loss='binary_crossentropy',
                optimizer=Adam(learning_rate = 5e-4),
                metrics=[metrics])

baselineM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 10)      280
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 10)      910
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 218, 218, 10)      910
# _________________________________________________________________
# flatten (Flatten)            (None, 475240)            0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 475241
# =================================================================
# Total params: 477,341
# Trainable params: 477,341
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We also need to set a callback, to help us in getting better accuracy with efficient time usage.

# %%
# %load_ext tensorboard

# %%
#Tensorflow Callback
# %load_ext tensorboard
logdir = os.path.join("logs", "BaselineModel")
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("baseline_model.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# We can now finally train our model

# %%
baseHistory = baselineM.fit(
            train,
            callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()],
            epochs    = 20,
            steps_per_epoch  = len(train),
            validation_data  = valid,
            validation_steps = len(valid))

baselineM = keras.models.load_model('baseline_model.h5')
# Out:
# Epoch 1/20
# 16/16 [==============================] - 113s 7s/step - loss: 1.6513 - accuracy: 0.5206 - precision: 0.5049 - recall: 0.5945 - auc: 0.5442 - val_loss: 0.6176 - val_accuracy: 0.7656 - val_precision: 0.7260 - val_recall: 0.8413 - val_auc: 0.8359
# val / train : 0.47
# Epoch 2/20
# 16/16 [==============================] - 67s 4s/step - loss: 0.6650 - accuracy: 0.5815 - precision: 0.5613 - recall: 0.7701 - auc: 0.6737 - val_loss: 0.6370 - val_accuracy: 0.5938 - val_precision: 1.0000 - val_recall: 0.1746 - val_auc: 0.8862
# val / train : 0.95
# Epoch 3/20
# 16/16 [==============================] - 67s 4s/step - loss: 0.5960 - accuracy: 0.7266 - precision: 0.8594 - recall: 0.5301 - auc: 0.8394 - val_loss: 0.5083 - val_accuracy: 0.8047 - val_precision: 0.8393 - val_recall: 0.7460 - val_auc: 0.8736
# val / train : 0.87
# Epoch 4/20
# 16/16 [==============================] - 67s 4s/step - loss: 0.5072 - accuracy: 0.7505 - precision: 0.7841 - recall: 0.7238 - auc: 0.8459 - val_loss: 0.4464 - val_accuracy: 0.8125 - val_precision: 0.8545 - val_recall: 0.7460 - val_auc: 0.8836
# val / train : 0.89
# Epoch 5/20
# 16/16 [==============================] - 67s 4s/step - loss: 0.3993 - accuracy: 0.8364 - precision: 0.8654 - recall: 0.7871 - auc: 0.9128 - val_loss: 0.4062 - val_accuracy: 0.8594 - val_precision: 0.9245 - val_recall: 0.7778 - val_auc: 0.9084
# val / train : 1.00
# Epoch 6/20
# 16/16 [==============================] - 67s 4s/step - loss: 0.3340 - accuracy: 0.8766 - precision: 0.9219 - recall: 0.8151 - auc: 0.9388 - val_loss: 0.3810 - val_accuracy: 0.8672 - val_precision: 0.8286 - val_recall: 0.9206 - val_auc: 0.9236
# val / train : 1.13
# Epoch 7/20
# 16/16 [==============================] - 68s 4s/step - loss: 0.3418 - accuracy: 0.8754 - precision: 0.8970 - recall: 0.8324 - auc: 0.9316 - val_loss: 0.3867 - val_accuracy: 0.8281 - val_precision: 0.7887 - val_recall: 0.8889 - val_auc: 0.9199
# val / train : 1.16
# Epoch 8/20
# 16/16 [==============================] - 67s 4s/step - loss: 0.2590 - accuracy: 0.9035 - precision: 0.8910 - recall: 0.9182 - auc: 0.9663 - val_loss: 0.4079 - val_accuracy: 0.8594 - val_precision: 0.9245 - val_recall: 0.7778 - val_auc: 0.9187
# val / train : 1.50
# Epoch 9/20
# 16/16 [==============================] - 67s 4s/step - loss: 0.2082 - accuracy: 0.9390 - precision: 0.9360 - recall: 0.9415 - auc: 0.9862 - val_loss: 0.3642 - val_accuracy: 0.8672 - val_precision: 0.9107 - val_recall: 0.8095 - val_auc: 0.9220
# val / train : 1.60
# Epoch 10/20
# 16/16 [==============================] - 67s 4s/step - loss: 0.2018 - accuracy: 0.9128 - precision: 0.9389 - recall: 0.8791 - auc: 0.9850 - val_loss: 0.4083 - val_accuracy: 0.8438 - val_precision: 0.8909 - val_recall: 0.7778 - val_auc: 0.9206
# val / train : 2.10
# Epoch 11/20
# 16/16 [==============================] - 68s 4s/step - loss: 0.1524 - accuracy: 0.9633 - precision: 0.9690 - recall: 0.9551 - auc: 0.9937 - val_loss: 0.3842 - val_accuracy: 0.8672 - val_precision: 0.9107 - val_recall: 0.8095 - val_auc: 0.9326
# val / train : 2.70
# Epoch 12/20
# 16/16 [==============================] - 67s 4s/step - loss: 0.0877 - accuracy: 0.9907 - precision: 1.0000 - recall: 0.9793 - auc: 0.9995 - val_loss: 0.3969 - val_accuracy: 0.8594 - val_precision: 0.8261 - val_recall: 0.9048 - val_auc: 0.9291
# val / train : 4.61
# Epoch 13/20
# 16/16 [==============================] - 67s 4s/step - loss: 0.0603 - accuracy: 0.9955 - precision: 1.0000 - recall: 0.9912 - auc: 1.0000 - val_loss: 0.3841 - val_accuracy: 0.8672 - val_precision: 0.8710 - val_recall: 0.8571 - val_auc: 0.9348
# val / train : 6.50
# Epoch 14/20
# 16/16 [==============================] - 67s 4s/step - loss: 0.0388 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - auc: 1.0000 - val_loss: 0.4088 - val_accuracy: 0.8594 - val_precision: 0.8689 - val_recall: 0.8413 - val_auc: 0.9330
# val / train : 10.63

# %% [markdown]
# We can see that the val/train loss is getting bigger and bigger each time the epoch ends. It can be concluded that this model is overfiting towards the training data

# %%
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-3425e976576a4152" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3425e976576a4152");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
def plot_training_hist(keras_model):
    '''
    Plot training History
    Creates two plots of model training logs
    '''
    hist = keras_model.history
    style.use('fivethirtyeight')
    
    # Loss Plot
    fig = plt.figure(figsize=(8,3))
    plt.title('Loss Plot')
    plt.plot(hist['loss'], '#07e9ed')
    plt.plot(hist['val_loss'], '#0791ed')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.ylim([0,1.2 * max(max(hist['loss'], hist['val_loss']))])
    plt.legend(['train', 'validation'], loc='lower right')
    plt.show()
    
    # Accuracy Plot
    fig = plt.figure(figsize=(8,3))
    plt.title('Accuracy Plot')
    plt.plot(hist['accuracy'], '#07e9ed')
    plt.plot(hist['val_accuracy'], '#0791ed')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')    
    plt.legend(['train', 'validation'], loc='lower right')
    plt.ylim([0,1])
    
    #ROC Plot
    fig = plt.figure(figsize=(8,3))
    plt.title('AUC Plot')
    plt.plot(hist['auc'], '#07e9ed')
    plt.plot(hist['val_auc'], '#0791ed')
    plt.xlabel('Epochs')
    plt.ylabel('AUC Score')    
    plt.legend(['train', 'validation'], loc='lower right')
    plt.ylim([0,1])
    # Show Plot, reset style
    plt.show()
    style.use('default')

# %%
plot_training_hist(baseHistory)

# %% [markdown]
# It is quite good, but we can still improve it with augmented data. Augmented data has proven to help the model to be less overfit, and become a better one when predicting unseen dataset.

# %% [markdown]
# # Augmented Training Data

# %% [markdown]
# Data augmentation plays a major role in making our data more diverse to prevent overfitting towards our model, especially when our dataset is small enough to be used on real world datasets.

# %%
train_df.shape
# Out:
# (512, 2)

# %% [markdown]
# We will still be using ImageDataGenerator to augment our training data

# %%
train_aug_generator = ImageDataGenerator(rescale = 1./255,
                                     zoom_range      = 0.05,
                                     shear_range     = 0,
                                     width_shift_range  = 0.05,
                                     height_shift_range = 0.05,
                                     )

train_aug = train_aug_generator.flow_from_dataframe(dataframe = train_df,
                                    class_mode  = 'binary',
                                    x_col       = 'Path',
                                    y_col       = 'Label',
                                    shuffle     = True,
                                    batch_size  = BATCH,
                                    target_size = IMAGE_INPUT,
                                    seed=19)
# Out:
# Found 512 validated image filenames belonging to 2 classes.

# %%
#Tensorflow Callback
# %load_ext tensorboard
logdir = os.path.join("logs", "BaselineModel-Augment")
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("baseline_augment.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# Now we can retrain our new model with augmented data

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

baselineM2 = Sequential([
  keras.layers.Conv2D(filters=10, 
                      kernel_size=3, 
                      strides=1,
                      padding='valid',
                      activation='relu', 
         input_shape=(224, 224, 3)), # input layer (specify input shape)
  keras.layers.Conv2D(10, 3, activation='relu'),
  keras.layers.Conv2D(10, 3, activation='relu'),
  keras.layers.Flatten(),
  Dense(1, activation='sigmoid') # output layer (specify output shape)
])

baselineM2.compile(loss='binary_crossentropy',
                optimizer=Adam(learning_rate = 5e-4),
                metrics=[metrics])

baselineM2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 10)      280
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 10)      910
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 218, 218, 10)      910
# _________________________________________________________________
# flatten (Flatten)            (None, 475240)            0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 475241
# =================================================================
# Total params: 477,341
# Trainable params: 477,341
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseHistory2 = baselineM2.fit(
            train_aug,
            callbacks = [callbacks],
            epochs    = 20,
            steps_per_epoch  = len(train),
            validation_data  = valid,
            validation_steps = len(valid))

baselineM2 = keras.models.load_model('baseline_augment.h5')
# Out:
# Epoch 1/20
# 16/16 [==============================] - 76s 5s/step - loss: 2.5731 - accuracy: 0.4776 - precision: 0.4728 - recall: 0.6215 - auc: 0.6569 - val_loss: 0.9577 - val_accuracy: 0.4922 - val_precision: 0.4922 - val_recall: 1.0000 - val_auc: 0.6118
# val / train : 0.51
# Epoch 2/20
# 16/16 [==============================] - 72s 4s/step - loss: 0.8264 - accuracy: 0.4834 - precision: 0.4797 - recall: 0.9745 - auc: 0.5231 - val_loss: 0.7006 - val_accuracy: 0.2969 - val_precision: 0.3548 - val_recall: 0.5238 - val_auc: 0.2602
# val / train : 0.94
# Epoch 3/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.6948 - accuracy: 0.4391 - precision: 0.4440 - recall: 0.6604 - auc: 0.4460 - val_loss: 0.6962 - val_accuracy: 0.2812 - val_precision: 0.2899 - val_recall: 0.3175 - val_auc: 0.3321
# val / train : 1.00
# Epoch 4/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.6888 - accuracy: 0.5197 - precision: 0.5741 - recall: 0.2490 - auc: 0.6330 - val_loss: 0.6808 - val_accuracy: 0.5078 - val_precision: 0.5000 - val_recall: 0.0159 - val_auc: 0.5741
# val / train : 0.99
# Epoch 5/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.6764 - accuracy: 0.5087 - precision: 0.8609 - recall: 0.0284 - auc: 0.6717 - val_loss: 0.6637 - val_accuracy: 0.5469 - val_precision: 0.6923 - val_recall: 0.1429 - val_auc: 0.6791
# val / train : 0.98
# Epoch 6/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.6632 - accuracy: 0.6138 - precision: 0.8080 - recall: 0.2368 - auc: 0.7004 - val_loss: 0.6521 - val_accuracy: 0.6641 - val_precision: 0.7632 - val_recall: 0.4603 - val_auc: 0.7122
# val / train : 0.98
# Epoch 7/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.6345 - accuracy: 0.6487 - precision: 0.7727 - recall: 0.4061 - auc: 0.7618 - val_loss: 0.6128 - val_accuracy: 0.6641 - val_precision: 0.6220 - val_recall: 0.8095 - val_auc: 0.7519
# val / train : 0.97
# Epoch 8/20
# 16/16 [==============================] - 71s 4s/step - loss: 0.6068 - accuracy: 0.6875 - precision: 0.6414 - recall: 0.6886 - auc: 0.7377 - val_loss: 0.5785 - val_accuracy: 0.6875 - val_precision: 0.6420 - val_recall: 0.8254 - val_auc: 0.7802
# val / train : 0.96
# Epoch 9/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.5711 - accuracy: 0.6960 - precision: 0.6813 - recall: 0.6838 - auc: 0.7827 - val_loss: 0.5912 - val_accuracy: 0.6875 - val_precision: 0.6322 - val_recall: 0.8730 - val_auc: 0.7845
# val / train : 1.00
# Epoch 10/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.6226 - accuracy: 0.6812 - precision: 0.6615 - recall: 0.7162 - auc: 0.7185 - val_loss: 0.5688 - val_accuracy: 0.6797 - val_precision: 0.6222 - val_recall: 0.8889 - val_auc: 0.7963
# val / train : 0.96
# Epoch 11/20
# 16/16 [==============================] - 72s 4s/step - loss: 0.5581 - accuracy: 0.7176 - precision: 0.7053 - recall: 0.7197 - auc: 0.7896 - val_loss: 0.5795 - val_accuracy: 0.6719 - val_precision: 0.6154 - val_recall: 0.8889 - val_auc: 0.8038
# val / train : 1.06
# Epoch 12/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.5822 - accuracy: 0.6840 - precision: 0.6631 - recall: 0.7401 - auc: 0.7641 - val_loss: 0.5495 - val_accuracy: 0.6875 - val_precision: 0.6386 - val_recall: 0.8413 - val_auc: 0.8170
# val / train : 0.95
# Epoch 13/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.5386 - accuracy: 0.7499 - precision: 0.7642 - recall: 0.7166 - auc: 0.8044 - val_loss: 0.5450 - val_accuracy: 0.7188 - val_precision: 0.6753 - val_recall: 0.8254 - val_auc: 0.8122
# val / train : 0.98
# Epoch 14/20
# 16/16 [==============================] - 71s 4s/step - loss: 0.5718 - accuracy: 0.7246 - precision: 0.7403 - recall: 0.6627 - auc: 0.7829 - val_loss: 0.5532 - val_accuracy: 0.6953 - val_precision: 0.6429 - val_recall: 0.8571 - val_auc: 0.8107
# val / train : 0.99
# Epoch 15/20
# 16/16 [==============================] - 72s 4s/step - loss: 0.5535 - accuracy: 0.7326 - precision: 0.7135 - recall: 0.7564 - auc: 0.7975 - val_loss: 0.5494 - val_accuracy: 0.7031 - val_precision: 0.6471 - val_recall: 0.8730 - val_auc: 0.8173
# val / train : 1.00
# Epoch 16/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.5288 - accuracy: 0.7456 - precision: 0.7434 - recall: 0.7651 - auc: 0.8161 - val_loss: 0.5185 - val_accuracy: 0.7266 - val_precision: 0.6892 - val_recall: 0.8095 - val_auc: 0.8284
# val / train : 0.95
# Epoch 17/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5145 - accuracy: 0.7453 - precision: 0.7667 - recall: 0.6932 - auc: 0.8306 - val_loss: 0.5098 - val_accuracy: 0.7344 - val_precision: 0.6883 - val_recall: 0.8413 - val_auc: 0.8409
# val / train : 0.97
# Epoch 18/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.5178 - accuracy: 0.7364 - precision: 0.7186 - recall: 0.7370 - auc: 0.8228 - val_loss: 0.5048 - val_accuracy: 0.7266 - val_precision: 0.6795 - val_recall: 0.8413 - val_auc: 0.8513
# val / train : 1.00
# Epoch 19/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5070 - accuracy: 0.7569 - precision: 0.7501 - recall: 0.7498 - auc: 0.8314 - val_loss: 0.5197 - val_accuracy: 0.7266 - val_precision: 0.6628 - val_recall: 0.9048 - val_auc: 0.8678
# val / train : 1.05
# Epoch 20/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.5037 - accuracy: 0.7403 - precision: 0.7248 - recall: 0.8048 - auc: 0.8383 - val_loss: 0.4786 - val_accuracy: 0.7656 - val_precision: 0.7619 - val_recall: 0.7619 - val_auc: 0.8556
# val / train : 0.88

# %%
plot_training_hist(baseHistory2)

# %% [markdown]
# It is way better than the previous overfit model! So we will use this augmented dataset for other training too. From previous training, lowering the learning rate didn't give any major improvement. Hence, we will move on to the pretrained model

# %% [markdown]
# # Use Pretrained Model

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers

# %% [markdown]
# We will now use a pretrained model tu achieve a better result

# %%
def create_model(model_url, num_classes=10):
  """Takes a TensorFlow Hub URL and creates a Keras Sequential model with it.
  
  Args:
    model_url (str): A TensorFlow Hub feature extraction URL.
    num_classes (int): Number of output neurons in output layer,
      should be equal to number of target classes, default 10.

  Returns:
    An uncompiled Keras Sequential model with model_url as feature
    extractor layer and Dense output layer with num_classes outputs.
  """
  # Download the pretrained model and save it as a Keras layer
  feature_extractor_layer = hub.KerasLayer(model_url,
                                           trainable=False, # freeze the underlying patterns
                                           name='feature_extraction_layer',
                                           input_shape=IMAGE_INPUT+(3,)) # define the input image shape
  
  # Create our own model
  model = tf.keras.Sequential([
    feature_extractor_layer, # use the feature extraction layer as the base
    layers.Dense(num_classes, activation='sigmoid', name='output_layer') # create our own output layer      
  ])

  return model

# %% [markdown]
# ## ResNet50

# %% [markdown]
# Resnet50 URL

# %%
resnet50_url = 'https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/5'

# %%
#Tensorflow Callback
# %load_ext tensorboard
logdir = os.path.join("logs", "resnet50")
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("resnet_model.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

resnet_model = create_model(resnet50_url, 1)

# Compile
resnet_model.compile(loss='binary_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(learning_rate = 5e-4),
                     metrics=[metrics])

# %%
resnet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature_extraction_layer (Ke (None, 2048)              23564800
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 2049
# =================================================================
# Total params: 23,566,849
# Trainable params: 2,049
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
resnet_history = resnet_model.fit(
            train_aug,
            callbacks = [callbacks],
            epochs    = 20,
            steps_per_epoch  = len(train),
            validation_data  = valid,
            validation_steps = len(valid))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 81s 5s/step - loss: 0.7142 - accuracy: 0.5473 - precision: 0.5539 - recall: 0.6416 - auc: 0.6900 - val_loss: 0.6730 - val_accuracy: 0.5469 - val_precision: 0.5510 - val_recall: 0.4286 - val_auc: 0.6129
# val / train : 0.95
# Epoch 2/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.6572 - accuracy: 0.6201 - precision: 0.6571 - recall: 0.4864 - auc: 0.6705 - val_loss: 0.6173 - val_accuracy: 0.6094 - val_precision: 0.5823 - val_recall: 0.7302 - val_auc: 0.7083
# val / train : 0.96
# Epoch 3/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.6095 - accuracy: 0.6779 - precision: 0.6885 - recall: 0.7140 - auc: 0.7385 - val_loss: 0.5792 - val_accuracy: 0.6641 - val_precision: 0.7273 - val_recall: 0.5079 - val_auc: 0.7756
# val / train : 0.97
# Epoch 4/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5859 - accuracy: 0.7106 - precision: 0.7882 - recall: 0.5620 - auc: 0.7701 - val_loss: 0.5523 - val_accuracy: 0.6875 - val_precision: 0.6353 - val_recall: 0.8571 - val_auc: 0.8127
# val / train : 0.97
# Epoch 5/20
# 16/16 [==============================] - 72s 4s/step - loss: 0.5610 - accuracy: 0.7265 - precision: 0.7253 - recall: 0.6920 - auc: 0.8028 - val_loss: 0.5173 - val_accuracy: 0.7266 - val_precision: 0.6944 - val_recall: 0.7937 - val_auc: 0.8360
# val / train : 0.94
# Epoch 6/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5086 - accuracy: 0.7497 - precision: 0.7435 - recall: 0.7426 - auc: 0.8495 - val_loss: 0.4956 - val_accuracy: 0.7578 - val_precision: 0.7424 - val_recall: 0.7778 - val_auc: 0.8521
# val / train : 0.94
# Epoch 7/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5164 - accuracy: 0.7868 - precision: 0.8316 - recall: 0.7544 - auc: 0.8477 - val_loss: 0.4778 - val_accuracy: 0.7891 - val_precision: 0.7903 - val_recall: 0.7778 - val_auc: 0.8658
# val / train : 0.94
# Epoch 8/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4977 - accuracy: 0.7956 - precision: 0.8333 - recall: 0.7354 - auc: 0.8515 - val_loss: 0.4662 - val_accuracy: 0.7734 - val_precision: 0.7361 - val_recall: 0.8413 - val_auc: 0.8735
# val / train : 0.93
# Epoch 9/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.5063 - accuracy: 0.7663 - precision: 0.7950 - recall: 0.7327 - auc: 0.8357 - val_loss: 0.4523 - val_accuracy: 0.7969 - val_precision: 0.7681 - val_recall: 0.8413 - val_auc: 0.8823
# val / train : 0.92
# Epoch 10/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4489 - accuracy: 0.8183 - precision: 0.8521 - recall: 0.7618 - auc: 0.8857 - val_loss: 0.4483 - val_accuracy: 0.7734 - val_precision: 0.7297 - val_recall: 0.8571 - val_auc: 0.8864
# val / train : 0.94
# Epoch 11/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4724 - accuracy: 0.7920 - precision: 0.7923 - recall: 0.7529 - auc: 0.8670 - val_loss: 0.4414 - val_accuracy: 0.7734 - val_precision: 0.7361 - val_recall: 0.8413 - val_auc: 0.8878
# val / train : 0.96
# Epoch 12/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.4763 - accuracy: 0.7827 - precision: 0.8053 - recall: 0.7524 - auc: 0.8599 - val_loss: 0.4341 - val_accuracy: 0.7891 - val_precision: 0.7500 - val_recall: 0.8571 - val_auc: 0.8929
# val / train : 0.95
# Epoch 13/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.4536 - accuracy: 0.7952 - precision: 0.8126 - recall: 0.7713 - auc: 0.8782 - val_loss: 0.4203 - val_accuracy: 0.7969 - val_precision: 0.7761 - val_recall: 0.8254 - val_auc: 0.8988
# val / train : 0.92
# Epoch 14/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4464 - accuracy: 0.8049 - precision: 0.8273 - recall: 0.7473 - auc: 0.8825 - val_loss: 0.4167 - val_accuracy: 0.7969 - val_precision: 0.7606 - val_recall: 0.8571 - val_auc: 0.9032
# val / train : 0.93
# Epoch 15/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4400 - accuracy: 0.8153 - precision: 0.8012 - recall: 0.8303 - auc: 0.8869 - val_loss: 0.4052 - val_accuracy: 0.8125 - val_precision: 0.8000 - val_recall: 0.8254 - val_auc: 0.9056
# val / train : 0.92
# Epoch 16/20
# 16/16 [==============================] - 71s 4s/step - loss: 0.4326 - accuracy: 0.8197 - precision: 0.8644 - recall: 0.7672 - auc: 0.8965 - val_loss: 0.4045 - val_accuracy: 0.8125 - val_precision: 0.7910 - val_recall: 0.8413 - val_auc: 0.9053
# val / train : 0.92
# Epoch 17/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4111 - accuracy: 0.8187 - precision: 0.8369 - recall: 0.7823 - auc: 0.9067 - val_loss: 0.4053 - val_accuracy: 0.7891 - val_precision: 0.7500 - val_recall: 0.8571 - val_auc: 0.9063
# val / train : 0.97
# Epoch 18/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4134 - accuracy: 0.8189 - precision: 0.8514 - recall: 0.7620 - auc: 0.9013 - val_loss: 0.4000 - val_accuracy: 0.8125 - val_precision: 0.7826 - val_recall: 0.8571 - val_auc: 0.9072
# val / train : 0.94
# Epoch 19/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.4063 - accuracy: 0.8460 - precision: 0.8525 - recall: 0.8391 - auc: 0.9061 - val_loss: 0.3929 - val_accuracy: 0.8359 - val_precision: 0.8182 - val_recall: 0.8571 - val_auc: 0.9093
# val / train : 0.94
# Epoch 20/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.4221 - accuracy: 0.8080 - precision: 0.8100 - recall: 0.7695 - auc: 0.8913 - val_loss: 0.4054 - val_accuracy: 0.7969 - val_precision: 0.7467 - val_recall: 0.8889 - val_auc: 0.9115
# val / train : 0.96

# %%
# resnet_model = keras.models.load_model('resnet_model.h5')

# %%
plot_training_hist(resnet_history)

# %% [markdown]
# It has a big improvement in both the Loss and Val_Loss, accuracy and also auc! we can now train with other model to look for the best architecture

# %% [markdown]
# ## EfficientNet

# %% [markdown]
# EfficientNet is know to have a better and faster model training compared to ResNet, so we will try to use it in our next modelling

# %% [markdown]
# ### EfficientNet B0

# %%
EFFB0_url = 'https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1'

# %%
#Tensorflow Callback
# %load_ext tensorboard
logdir = os.path.join("logs", "efficientb0")
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("efficientb0_model.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

efficientb0 = create_model(EFFB0_url, 1)

# Compile
efficientb0.compile(loss='binary_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(learning_rate = 5e-4),
                     metrics=[metrics])

# %%
efficientb0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature_extraction_layer (Ke (None, 1280)              4049564
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 1281
# =================================================================
# Total params: 4,050,845
# Trainable params: 1,281
# Non-trainable params: 4,049,564
# _________________________________________________________________

# %%
efficientb0_history = efficientb0.fit(
            train_aug,
            callbacks = [callbacks],
            epochs    = 20,
            steps_per_epoch  = len(train),
            validation_data  = valid,
            validation_steps = len(valid))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 87s 5s/step - loss: 0.6755 - accuracy: 0.5756 - precision: 0.7900 - recall: 0.4723 - auc: 0.7319 - val_loss: 0.6489 - val_accuracy: 0.6406 - val_precision: 0.5914 - val_recall: 0.8730 - val_auc: 0.7365
# val / train : 0.96
# Epoch 2/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.6414 - accuracy: 0.6329 - precision: 0.5986 - recall: 0.7945 - auc: 0.7437 - val_loss: 0.6022 - val_accuracy: 0.7500 - val_precision: 0.8780 - val_recall: 0.5714 - val_auc: 0.8293
# val / train : 0.96
# Epoch 3/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.6007 - accuracy: 0.7363 - precision: 0.8005 - recall: 0.5659 - auc: 0.7809 - val_loss: 0.5679 - val_accuracy: 0.7891 - val_precision: 0.9286 - val_recall: 0.6190 - val_auc: 0.8675
# val / train : 0.94
# Epoch 4/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5580 - accuracy: 0.7985 - precision: 0.8091 - recall: 0.7759 - auc: 0.8459 - val_loss: 0.5393 - val_accuracy: 0.8359 - val_precision: 0.9200 - val_recall: 0.7302 - val_auc: 0.8851
# val / train : 0.95
# Epoch 5/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5662 - accuracy: 0.7685 - precision: 0.8111 - recall: 0.7024 - auc: 0.8038 - val_loss: 0.5193 - val_accuracy: 0.8516 - val_precision: 0.9783 - val_recall: 0.7143 - val_auc: 0.8946
# val / train : 0.94
# Epoch 6/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5492 - accuracy: 0.7772 - precision: 0.8235 - recall: 0.7032 - auc: 0.8184 - val_loss: 0.5008 - val_accuracy: 0.8438 - val_precision: 0.9574 - val_recall: 0.7143 - val_auc: 0.9028
# val / train : 0.92
# Epoch 7/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5000 - accuracy: 0.8101 - precision: 0.8531 - recall: 0.7727 - auc: 0.8659 - val_loss: 0.4891 - val_accuracy: 0.8438 - val_precision: 0.9574 - val_recall: 0.7143 - val_auc: 0.9031
# val / train : 0.94
# Epoch 8/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4946 - accuracy: 0.7926 - precision: 0.8308 - recall: 0.7008 - auc: 0.8699 - val_loss: 0.4812 - val_accuracy: 0.8359 - val_precision: 0.9773 - val_recall: 0.6825 - val_auc: 0.9054
# val / train : 0.94
# Epoch 9/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5042 - accuracy: 0.7909 - precision: 0.8140 - recall: 0.7177 - auc: 0.8488 - val_loss: 0.4673 - val_accuracy: 0.8516 - val_precision: 0.8548 - val_recall: 0.8413 - val_auc: 0.9078
# val / train : 0.94
# Epoch 10/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5012 - accuracy: 0.7732 - precision: 0.7969 - recall: 0.7445 - auc: 0.8506 - val_loss: 0.4655 - val_accuracy: 0.8594 - val_precision: 0.9787 - val_recall: 0.7302 - val_auc: 0.9046
# val / train : 0.95
# Epoch 11/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4820 - accuracy: 0.8192 - precision: 0.8933 - recall: 0.7303 - auc: 0.8686 - val_loss: 0.4581 - val_accuracy: 0.8672 - val_precision: 0.9423 - val_recall: 0.7778 - val_auc: 0.9057
# val / train : 0.95
# Epoch 12/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4640 - accuracy: 0.8174 - precision: 0.8782 - recall: 0.7429 - auc: 0.8835 - val_loss: 0.4502 - val_accuracy: 0.8516 - val_precision: 0.9074 - val_recall: 0.7778 - val_auc: 0.9048
# val / train : 0.94
# Epoch 13/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4681 - accuracy: 0.7971 - precision: 0.8173 - recall: 0.7602 - auc: 0.8753 - val_loss: 0.4494 - val_accuracy: 0.8438 - val_precision: 0.9388 - val_recall: 0.7302 - val_auc: 0.9043
# val / train : 0.96
# Epoch 14/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4367 - accuracy: 0.8398 - precision: 0.8886 - recall: 0.7608 - auc: 0.9010 - val_loss: 0.4421 - val_accuracy: 0.8438 - val_precision: 0.8525 - val_recall: 0.8254 - val_auc: 0.9060
# val / train : 0.97
# Epoch 15/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4783 - accuracy: 0.7932 - precision: 0.8384 - recall: 0.7274 - auc: 0.8576 - val_loss: 0.4401 - val_accuracy: 0.8516 - val_precision: 0.8929 - val_recall: 0.7937 - val_auc: 0.9046
# val / train : 0.96
# Epoch 16/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4803 - accuracy: 0.7932 - precision: 0.8312 - recall: 0.7279 - auc: 0.8516 - val_loss: 0.4356 - val_accuracy: 0.8438 - val_precision: 0.9216 - val_recall: 0.7460 - val_auc: 0.9060
# val / train : 0.94
# Epoch 17/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4516 - accuracy: 0.8175 - precision: 0.8397 - recall: 0.7553 - auc: 0.8861 - val_loss: 0.4316 - val_accuracy: 0.8516 - val_precision: 0.8929 - val_recall: 0.7937 - val_auc: 0.9050
# val / train : 0.94
# Epoch 18/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4465 - accuracy: 0.8024 - precision: 0.8392 - recall: 0.7295 - auc: 0.8844 - val_loss: 0.4312 - val_accuracy: 0.8516 - val_precision: 0.8929 - val_recall: 0.7937 - val_auc: 0.9050
# val / train : 0.97
# Epoch 19/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4650 - accuracy: 0.8055 - precision: 0.8377 - recall: 0.7560 - auc: 0.8675 - val_loss: 0.4282 - val_accuracy: 0.8438 - val_precision: 0.8772 - val_recall: 0.7937 - val_auc: 0.9057
# val / train : 0.94
# Epoch 20/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4263 - accuracy: 0.8376 - precision: 0.8911 - recall: 0.7726 - auc: 0.8957 - val_loss: 0.4300 - val_accuracy: 0.8359 - val_precision: 0.8750 - val_recall: 0.7778 - val_auc: 0.9024
# val / train : 1.00

# %%
# efficientb0 = keras.models.load_model('efficientb0_model.h5')

# %%
plot_training_hist(efficientb0_history)

# %% [markdown]
# ### EfficientNet B1

# %%
EFFB1_url = 'https://tfhub.dev/tensorflow/efficientnet/b1/feature-vector/1'

# %%
#Tensorflow Callback
# %load_ext tensorboard
logdir = os.path.join("logs", "efficientb1")
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("efficientb1_model.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

efficientb1 = create_model(EFFB1_url, 1)

# Compile
efficientb1.compile(loss='binary_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(learning_rate = 5e-4),
                     metrics=[metrics])

# %%
efficientb1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature_extraction_layer (Ke (None, 1280)              6575232
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 1281
# =================================================================
# Total params: 6,576,513
# Trainable params: 1,281
# Non-trainable params: 6,575,232
# _________________________________________________________________

# %% [markdown]
# The params for the efficientnet-b1 is 1/3 of the resnet50, and known to have a better result. It is really worth to try with less time computation, who knows that we can get a better result in accuracy, loss and auc.

# %%
efficient_history = efficientb1.fit(
            train_aug,
            callbacks = [callbacks],
            epochs    = 20,
            steps_per_epoch  = len(train),
            validation_data  = valid,
            validation_steps = len(valid))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 94s 5s/step - loss: 0.7005 - accuracy: 0.5411 - precision: 0.5404 - recall: 0.7250 - auc: 0.7217 - val_loss: 0.6378 - val_accuracy: 0.6797 - val_precision: 0.7391 - val_recall: 0.5397 - val_auc: 0.7336
# val / train : 0.92
# Epoch 2/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.6494 - accuracy: 0.6523 - precision: 0.6870 - recall: 0.4367 - auc: 0.6716 - val_loss: 0.5934 - val_accuracy: 0.7734 - val_precision: 0.8036 - val_recall: 0.7143 - val_auc: 0.8200
# val / train : 0.90
# Epoch 3/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.6218 - accuracy: 0.6849 - precision: 0.6489 - recall: 0.7515 - auc: 0.7522 - val_loss: 0.5630 - val_accuracy: 0.7891 - val_precision: 0.7647 - val_recall: 0.8254 - val_auc: 0.8557
# val / train : 0.92
# Epoch 4/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5969 - accuracy: 0.7271 - precision: 0.7135 - recall: 0.6857 - auc: 0.8010 - val_loss: 0.5361 - val_accuracy: 0.7969 - val_precision: 0.8491 - val_recall: 0.7143 - val_auc: 0.8709
# val / train : 0.90
# Epoch 5/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5682 - accuracy: 0.7323 - precision: 0.7175 - recall: 0.7271 - auc: 0.8099 - val_loss: 0.5155 - val_accuracy: 0.8125 - val_precision: 0.8305 - val_recall: 0.7778 - val_auc: 0.8790
# val / train : 0.90
# Epoch 6/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5630 - accuracy: 0.7342 - precision: 0.7535 - recall: 0.7089 - auc: 0.8223 - val_loss: 0.4968 - val_accuracy: 0.8047 - val_precision: 0.8276 - val_recall: 0.7619 - val_auc: 0.8890
# val / train : 0.90
# Epoch 7/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5682 - accuracy: 0.7149 - precision: 0.7566 - recall: 0.6439 - auc: 0.7995 - val_loss: 0.4849 - val_accuracy: 0.8047 - val_precision: 0.8276 - val_recall: 0.7619 - val_auc: 0.8968
# val / train : 0.89
# Epoch 8/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5249 - accuracy: 0.7659 - precision: 0.7831 - recall: 0.7419 - auc: 0.8511 - val_loss: 0.4739 - val_accuracy: 0.8047 - val_precision: 0.8276 - val_recall: 0.7619 - val_auc: 0.8956
# val / train : 0.91
# Epoch 9/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4891 - accuracy: 0.7904 - precision: 0.8108 - recall: 0.7559 - auc: 0.8920 - val_loss: 0.4618 - val_accuracy: 0.8047 - val_precision: 0.8167 - val_recall: 0.7778 - val_auc: 0.8996
# val / train : 0.92
# Epoch 10/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4944 - accuracy: 0.7870 - precision: 0.7811 - recall: 0.7976 - auc: 0.8738 - val_loss: 0.4506 - val_accuracy: 0.8203 - val_precision: 0.8448 - val_recall: 0.7778 - val_auc: 0.9027
# val / train : 0.89
# Epoch 11/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5097 - accuracy: 0.7671 - precision: 0.7756 - recall: 0.7448 - auc: 0.8485 - val_loss: 0.4451 - val_accuracy: 0.7969 - val_precision: 0.8033 - val_recall: 0.7778 - val_auc: 0.9033
# val / train : 0.87
# Epoch 12/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5072 - accuracy: 0.7936 - precision: 0.7854 - recall: 0.7904 - auc: 0.8512 - val_loss: 0.4425 - val_accuracy: 0.7969 - val_precision: 0.7937 - val_recall: 0.7937 - val_auc: 0.9023
# val / train : 0.88
# Epoch 13/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4825 - accuracy: 0.8235 - precision: 0.8371 - recall: 0.7910 - auc: 0.8711 - val_loss: 0.4388 - val_accuracy: 0.8047 - val_precision: 0.7879 - val_recall: 0.8254 - val_auc: 0.9051
# val / train : 0.91
# Epoch 14/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4867 - accuracy: 0.7774 - precision: 0.7498 - recall: 0.8061 - auc: 0.8707 - val_loss: 0.4307 - val_accuracy: 0.8047 - val_precision: 0.8065 - val_recall: 0.7937 - val_auc: 0.9055
# val / train : 0.91
# Epoch 15/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4631 - accuracy: 0.7950 - precision: 0.8092 - recall: 0.7637 - auc: 0.8882 - val_loss: 0.4247 - val_accuracy: 0.7969 - val_precision: 0.7937 - val_recall: 0.7937 - val_auc: 0.9072
# val / train : 0.92
# Epoch 16/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.5075 - accuracy: 0.7844 - precision: 0.8094 - recall: 0.7238 - auc: 0.8441 - val_loss: 0.4211 - val_accuracy: 0.7969 - val_precision: 0.7937 - val_recall: 0.7937 - val_auc: 0.9083
# val / train : 0.88
# Epoch 17/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.4512 - accuracy: 0.8248 - precision: 0.8217 - recall: 0.8125 - auc: 0.8932 - val_loss: 0.4176 - val_accuracy: 0.8125 - val_precision: 0.8095 - val_recall: 0.8095 - val_auc: 0.9090
# val / train : 0.91
# Epoch 18/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4690 - accuracy: 0.7958 - precision: 0.8179 - recall: 0.7645 - auc: 0.8762 - val_loss: 0.4141 - val_accuracy: 0.8125 - val_precision: 0.8095 - val_recall: 0.8095 - val_auc: 0.9114
# val / train : 0.90
# Epoch 19/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.4220 - accuracy: 0.8340 - precision: 0.8519 - recall: 0.7996 - auc: 0.9093 - val_loss: 0.4132 - val_accuracy: 0.8203 - val_precision: 0.8226 - val_recall: 0.8095 - val_auc: 0.9101
# val / train : 0.93
# Epoch 20/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.4548 - accuracy: 0.8195 - precision: 0.8258 - recall: 0.7892 - auc: 0.8876 - val_loss: 0.4143 - val_accuracy: 0.7969 - val_precision: 0.7761 - val_recall: 0.8254 - val_auc: 0.9103
# val / train : 0.90

# %%
# efficientb1 = keras.models.load_model('efficientb1_model.h5')

# %%
plot_training_hist(efficient_history)

# %% [markdown]
# ## DenseNet

# %%
#Tensorflow Callback
# %load_ext tensorboard
logdir = os.path.join("logs", "densenet121")
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("densenet121.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [tensorboard_callback, checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)
from keras import layers

base_model = tf.keras.applications.densenet.DenseNet121(weights='imagenet', include_top = False)
base_model.trainable = False

inputs = layers.Input(shape=(224, 224, 3), name='input_layer')
out = base_model(inputs, training=False)
out = layers.GlobalMaxPooling2D()(out)
out = layers.Dense(128, activation='relu')(out)
out = layers.Dropout(0.2)(out)
out = layers.Dense(1, activation='sigmoid', name='output_layer')(out)
model_dense = keras.Model(inputs, out)

model_dense.compile(optimizer = keras.optimizers.Adam(learning_rate = 5e-4), loss = 'binary_crossentropy', metrics = [metrics])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step

# %%
dense121_history = model_dense.fit(
            train_aug,
            callbacks = [callbacks],
            epochs    = 20,
            steps_per_epoch  = len(train),
            validation_data  = valid,
            validation_steps = len(valid))
# Out:
# Epoch 1/20
# 16/16 [==============================] - 86s 5s/step - loss: 1.7209 - accuracy: 0.5017 - precision: 0.5430 - recall: 0.6335 - auc: 0.6024 - val_loss: 0.5763 - val_accuracy: 0.7031 - val_precision: 0.7193 - val_recall: 0.6508 - val_auc: 0.7663
# val / train : 0.40
# Epoch 2/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.9083 - accuracy: 0.6170 - precision: 0.6297 - recall: 0.4979 - auc: 0.6399 - val_loss: 0.5024 - val_accuracy: 0.7891 - val_precision: 0.7812 - val_recall: 0.7937 - val_auc: 0.8363
# val / train : 0.59
# Epoch 3/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.6946 - accuracy: 0.6910 - precision: 0.6848 - recall: 0.7017 - auc: 0.7363 - val_loss: 0.4814 - val_accuracy: 0.7812 - val_precision: 0.7465 - val_recall: 0.8413 - val_auc: 0.8543
# val / train : 0.69
# Epoch 4/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5549 - accuracy: 0.7468 - precision: 0.7504 - recall: 0.7129 - auc: 0.7970 - val_loss: 0.4547 - val_accuracy: 0.8359 - val_precision: 0.8889 - val_recall: 0.7619 - val_auc: 0.8750
# val / train : 0.80
# Epoch 5/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5655 - accuracy: 0.6992 - precision: 0.7109 - recall: 0.6031 - auc: 0.7974 - val_loss: 0.5349 - val_accuracy: 0.6719 - val_precision: 0.6154 - val_recall: 0.8889 - val_auc: 0.8802
# val / train : 0.89
# Epoch 6/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.6063 - accuracy: 0.7348 - precision: 0.7161 - recall: 0.7858 - auc: 0.7922 - val_loss: 0.4211 - val_accuracy: 0.8359 - val_precision: 0.8500 - val_recall: 0.8095 - val_auc: 0.8822
# val / train : 0.77
# Epoch 7/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4961 - accuracy: 0.7781 - precision: 0.7966 - recall: 0.7373 - auc: 0.8386 - val_loss: 0.4290 - val_accuracy: 0.8125 - val_precision: 0.8000 - val_recall: 0.8254 - val_auc: 0.8827
# val / train : 0.89
# Epoch 8/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.5180 - accuracy: 0.7315 - precision: 0.7194 - recall: 0.7719 - auc: 0.8232 - val_loss: 0.4600 - val_accuracy: 0.8203 - val_precision: 0.8571 - val_recall: 0.7619 - val_auc: 0.8674
# val / train : 0.96
# Epoch 9/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4549 - accuracy: 0.7690 - precision: 0.7954 - recall: 0.6846 - auc: 0.8703 - val_loss: 0.4594 - val_accuracy: 0.8281 - val_precision: 0.8727 - val_recall: 0.7619 - val_auc: 0.8730
# val / train : 1.03
# Epoch 10/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4767 - accuracy: 0.7898 - precision: 0.8265 - recall: 0.7346 - auc: 0.8616 - val_loss: 0.4503 - val_accuracy: 0.8359 - val_precision: 0.9200 - val_recall: 0.7302 - val_auc: 0.8856
# val / train : 0.96
# Epoch 11/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4362 - accuracy: 0.8113 - precision: 0.8431 - recall: 0.7428 - auc: 0.8827 - val_loss: 0.4070 - val_accuracy: 0.8281 - val_precision: 0.8154 - val_recall: 0.8413 - val_auc: 0.8947
# val / train : 0.97
# Epoch 12/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4419 - accuracy: 0.8031 - precision: 0.7786 - recall: 0.8317 - auc: 0.8832 - val_loss: 0.4071 - val_accuracy: 0.8203 - val_precision: 0.8030 - val_recall: 0.8413 - val_auc: 0.8971
# val / train : 0.95
# Epoch 13/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4173 - accuracy: 0.8042 - precision: 0.8187 - recall: 0.7770 - auc: 0.8889 - val_loss: 0.4148 - val_accuracy: 0.8438 - val_precision: 0.8413 - val_recall: 0.8413 - val_auc: 0.8855
# val / train : 0.94
# Epoch 14/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4474 - accuracy: 0.8067 - precision: 0.7960 - recall: 0.7742 - auc: 0.8668 - val_loss: 0.4163 - val_accuracy: 0.8516 - val_precision: 0.8929 - val_recall: 0.7937 - val_auc: 0.8897
# val / train : 0.98
# Epoch 15/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4256 - accuracy: 0.8159 - precision: 0.8560 - recall: 0.7696 - auc: 0.8917 - val_loss: 0.3937 - val_accuracy: 0.8516 - val_precision: 0.8548 - val_recall: 0.8413 - val_auc: 0.8938
# val / train : 0.93
# Epoch 16/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.3798 - accuracy: 0.8137 - precision: 0.8338 - recall: 0.7941 - auc: 0.9102 - val_loss: 0.3801 - val_accuracy: 0.8438 - val_precision: 0.8772 - val_recall: 0.7937 - val_auc: 0.9044
# val / train : 0.97
# Epoch 17/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4278 - accuracy: 0.8192 - precision: 0.8525 - recall: 0.7631 - auc: 0.8857 - val_loss: 0.3604 - val_accuracy: 0.8438 - val_precision: 0.8525 - val_recall: 0.8254 - val_auc: 0.9066
# val / train : 0.86
# Epoch 18/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.3711 - accuracy: 0.8234 - precision: 0.8120 - recall: 0.8324 - auc: 0.9205 - val_loss: 0.4278 - val_accuracy: 0.8047 - val_precision: 0.7639 - val_recall: 0.8730 - val_auc: 0.9001
# val / train : 1.03
# Epoch 19/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.3549 - accuracy: 0.8353 - precision: 0.8471 - recall: 0.8277 - auc: 0.9234 - val_loss: 0.4032 - val_accuracy: 0.8125 - val_precision: 0.7826 - val_recall: 0.8571 - val_auc: 0.9015
# val / train : 1.01
# Epoch 20/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4229 - accuracy: 0.8068 - precision: 0.8004 - recall: 0.8119 - auc: 0.8850 - val_loss: 0.3995 - val_accuracy: 0.8125 - val_precision: 0.7826 - val_recall: 0.8571 - val_auc: 0.9055
# val / train : 0.98

# %%
plot_training_hist(dense121_history)

# %% [markdown]
# ## Modelling Conclusion
#
# Model
#
# After trying several pretrained models, we get the ResNet50 pretrained model as the most stable, less overfit and good in getting the best scores in specified metrics (accuracy, auc, recall). Hence, we will use this model for further hyperparameter tuning, or adding layers.

# %% [markdown]
# |Model|Acc/Val_Acc|Loss/Val_Loss|Auc/Val_Auc|
# |---   |---   |---   |---   |
# |Baseline|0.7403/0.7656|0.5037/0.4786|0.8383/0.8556|
# |ResNet50 V2|0.8080/0.7969 |0.4221/0.4054| 0.8913/0.9115|
# |EfficientNetB0|0.8376/0.8359|0.4263/0.4300|0.8957/0.9024|
# |EfficientNetB1|0.8195/0.7969|0.4548/0.4143|0.8876/0.9103|
# |DenseNet121|0.8068/0.8125|0.4229/0.3995|0.8850/0.9055|

# %% [markdown]
# These table is generated from the previous trainings, and we can see that ResNet50 V2 pretrained model is the most stable model, even though EfficientNetB1 has a better result on the accuracy
