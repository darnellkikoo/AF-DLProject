# %%
import os
import gc
import re
import cv2
import sys
import glob
from glob import glob
import tensorflow as tf
import keras

import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style  as style
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix

from tqdm  import tqdm
from keras import backend
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from sklearn.metrics     import accuracy_score, roc_auc_score
from keras.layers        import Dense, Dropout, Flatten, BatchNormalization, GlobalMaxPooling2D
from keras.models        import Sequential, Model, load_model
from keras.callbacks     import ModelCheckpoint,ReduceLROnPlateau, CSVLogger
from keras.activations   import elu
from keras.engine        import Layer, InputSpec
from keras.applications  import MobileNetV2
from keras.optimizers    import Adam
from keras.preprocessing import image
from sklearn.model_selection   import train_test_split
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Data Preparation
#
# We will use the codes from previous notebook to extract all the data, images, dataframes and also the functions for modelling and also plotting

# %%
# Compose filenames
filelist_mt = glob('../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/*.png')
filelist_shenzen     = glob('../input/pulmonary-chest-xray-abnormalities/ChinaSet_AllFiles/ChinaSet_AllFiles/CXR_png/*.png')
filelist             = filelist_mt + filelist_shenzen

# %%
j = 0
for i in filelist:
    print(i)
    if j == 5:
        break
    j+=1
# Out:
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0017_0.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0020_0.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0030_0.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0013_0.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0354_1.png
# ../input/pulmonary-chest-xray-abnormalities/Montgomery/MontgomerySet/CXR_png/MCUCXR_0044_0.png

# %%
def extract_label(file_list):
    '''
    Label Extraction Function
    Reads a filename and extracts label from it
    '''
    labels = []
    for file in tqdm(file_list):
        current_label = re.findall('[0-9]{4}_(.+?).png', file)
#         print(current_label)
        labels.append(current_label[0])
    return(labels)

# %%
label = extract_label(filelist)
# Out:
# 100%|██████████| 800/800 [00:00<00:00, 186703.94it/s]

# %%
len(label)
# Out:
# 800

# %%
df = pd.DataFrame(filelist, columns = ['Path'])
df['Label'] = label

y = df['Label']
X = df.drop(['Label'], axis = 1)
X.shape, y.shape
# Out:
# ((800, 1), (800,))

# %% [markdown]
# ## Data Splitting
#
# As what we have done before, we will split the data into 80:20 for training and testing, and 80:20 for training and validation

# %%
#80% Training 20% Testing
df_train, X_test, label_train, y_test = train_test_split(X,
                                                         y,
                                                         stratify = y,
                                                         random_state = 19,
                                                         test_size = 0.2)

# %%
# 80% Training 20% Validation
X_train, X_valid, y_train, y_valid = train_test_split(df_train,
                                                     label_train,
                                                     stratify = label_train,
                                                     random_state = 19,
                                                     test_size = 0.2)

# %%
print('Train size')
print(X_train.shape, y_train.shape)
print('Validation Size')
print(X_valid.shape, y_valid.shape)
print('Testing Size')
print(X_test.shape, y_test.shape)
# Out:
# Train size
# (512, 1) (512,)
# Validation Size
# (128, 1) (128,)
# Testing Size
# (160, 1) (160,)

# %% [markdown]
# We will convert it into dataframe, to ease the process using the ImageDataGenerator by Keras

# %%
# Train
train_df = X_train.copy()
train_df['Label'] = y_train


#Valid
valid_df = X_valid.copy()
valid_df['Label'] = y_valid


#Test
test_df = X_test.copy()
test_df['Label'] = y_test

# %%
train_df.head()
# Out:
#                                                   Path Label
# 761  ../input/pulmonary-chest-xray-abnormalities/Ch...     1
# 577  ../input/pulmonary-chest-xray-abnormalities/Ch...     1
# 484  ../input/pulmonary-chest-xray-abnormalities/Ch...     0
# 299  ../input/pulmonary-chest-xray-abnormalities/Ch...     0
# 99   ../input/pulmonary-chest-xray-abnormalities/Mo...     1

# %%
print("Train Value Counts")
print(train_df['Label'].value_counts())
print("Validation DF Value Counts")
print(valid_df['Label'].value_counts())
print("Test DF Value Counts")
print(test_df['Label'].value_counts())
# Out:
# Train Value Counts
# 0    260
# 1    252
# Name: Label, dtype: int64
# Validation DF Value Counts
# 0    65
# 1    63
# Name: Label, dtype: int64
# Test DF Value Counts
# 0    81
# 1    79
# Name: Label, dtype: int64

# %%
def plot_multiple_images(image_dataframe, rows = 4, columns = 4, figsize = (16, 20), resize=(1024,1024), preprocessing=None):
    '''
    Plots Multiple Images
    Reads, resizes, applies preprocessing if desired and plots multiple images from a given dataframe
    '''
    image_dataframe = image_dataframe.reset_index(drop=True)
    fig, ax = plt.subplots(rows, columns, figsize=figsize)
#     print(image_dataframe)
    i = 1
    for j in range(rows):
        for k in range(columns):
            img = plt.imread(image_dataframe.loc[i-1,'Path'])
            img = cv2.resize(img, resize)
            if preprocessing:
                img = preprocessing(img)
            ax[j][k].set_title("Xray "+str(i))
            a = image_dataframe.loc[i-1, 'Label']
            if int(a) == 0:
                ax[j][k].set_xlabel('Normal')
            else:
                ax[j][k].set_xlabel('Tuberculosis')  
                
            ax[j][k].imshow(img, alpha=1, cmap='gray')
            i+=1
            
        if(i == (rows*columns)):
            break
    plt.show()

# %%
#Plotting Train images
plot_multiple_images(train_df)

# %%
#Plotting Test Images
plot_multiple_images(valid_df)

# %% [markdown]
# ## Setting up Train, Valid, Test Data from ImageDataGenerator

# %% [markdown]
# We'll cutdown the Image Input size to 224,224 to reduce time computation, and batch-size = 32

# %%
BATCH = 32
IMAGE_INPUT = (224, 224)

# %%
def cal_steps(num_images, batch_size):
   # calculates steps for generator
   steps = num_images // batch_size

   # adds 1 to the generator steps if the steps multiplied by
   # the batch size is less than the total training samples
   return steps + 1 if (steps * batch_size) < num_images else steps

# %%
#Creating Training Data Generator
tf.random.set_seed(19)
train_generator = ImageDataGenerator(rescale = 1./255,)

# Create Validation data generator
test_generator  = ImageDataGenerator(rescale = 1./255,)

# %% [markdown]
# Still the same from out previous notebook, we will give some augmentation to the training data. This is done to prevent overfitting, and give challenges to our model to overcome

# %%
#Training Data
train_aug_generator = ImageDataGenerator(rescale = 1./255,
                                     zoom_range      = 0.05,
                                     shear_range     = 0,
                                     width_shift_range  = 0.05,
                                     height_shift_range = 0.05,
                                     )

# %%
train = train_generator.flow_from_dataframe(dataframe = train_df,
                                    class_mode  = 'binary',
                                    x_col       = 'Path',
                                    y_col       = 'Label',
                                    shuffle     = True,
                                    batch_size  = BATCH,
                                    target_size = IMAGE_INPUT,
                                    seed=19)

train_aug = train_aug_generator.flow_from_dataframe(dataframe = train_df,
                                    class_mode  = 'binary',
                                    x_col       = 'Path',
                                    y_col       = 'Label',
                                    shuffle     = True,
                                    batch_size  = BATCH,
                                    target_size = IMAGE_INPUT,
                                    seed=19)
#Validation Data
valid = train_generator.flow_from_dataframe(dataframe = valid_df,
                                    class_mode  = 'binary',
                                    x_col       = 'Path',
                                    y_col       = 'Label',
                                    shuffle     = True,
                                    batch_size  = BATCH,
                                    target_size = IMAGE_INPUT,
                                    seed=19)

#Testing Data
test = test_generator.flow_from_dataframe(dataframe = test_df,
                                    class_mode  = 'binary',
                                    x_col       = 'Path',
                                    y_col       = 'Label',
                                    shuffle     = False,
                                    batch_size  = BATCH,
                                    target_size = IMAGE_INPUT)
# Out:
# Found 512 validated image filenames belonging to 2 classes.
# Found 512 validated image filenames belonging to 2 classes.
# Found 128 validated image filenames belonging to 2 classes.
# Found 160 validated image filenames belonging to 2 classes.

# %%
def plot_training_hist(keras_model):
    '''
    Plot training History
    Creates two plots of model training logs
    '''
    hist = keras_model.history
    style.use('fivethirtyeight')
    
    # Loss Plot
    fig = plt.figure(figsize=(8,3))
    plt.title('Loss Plot')
    plt.plot(hist['loss'], '#07e9ed')
    plt.plot(hist['val_loss'], '#0791ed')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.ylim([0,1.2 * max(max(hist['loss'], hist['val_loss']))])
    plt.legend(['train', 'validation'], loc='lower right')
    plt.show()
    
    # Accuracy Plot
    fig = plt.figure(figsize=(8,3))
    plt.title('Accuracy Plot')
    plt.plot(hist['accuracy'], '#07e9ed')
    plt.plot(hist['val_accuracy'], '#0791ed')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')    
    plt.legend(['train', 'validation'], loc='lower right')
    plt.ylim([0,1])
    
    #ROC Plot
    fig = plt.figure(figsize=(8,3))
    plt.title('Recall Plot')
    plt.plot(hist['recall'], '#07e9ed')
    plt.plot(hist['val_recall'], '#0791ed')
    plt.xlabel('Epochs')
    plt.ylabel('Recall Score')    
    plt.legend(['train', 'validation'], loc='lower right')
    plt.ylim([0,1])
    # Show Plot, reset style
    plt.show()
    style.use('default')

# %% [markdown]
# # Modelling

# %% [markdown]
# ## ResNet50 V2
# ![image.png](attachment:6bbbdf3b-f6eb-4c0f-a778-4bcf74220739.png)![image.png](attachment:da13518d-77ff-40b0-9833-d8764b9d826e.png)

# %% [markdown]
# ResNet, short for a Residual Networks are usually used for many Computer Vision Tasks. It is able to perform greatly on unseen data, which also won the ImageNet Challenge in 2015. After going through many comparison between ResNet50, EfficientNetB0, EfficientNetb1, and DenseNet121, This pretrained model shows a stability amongst all model. Hence, this model is chosen for further modelling, tuning and evaluation

# %% [markdown]
# ## Setting up Callbacks

# %%
# %load_ext tensorboard
logdir = os.path.join("logs", "BaselineModel")
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("baseline_model.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]

# %%
#Defining Metrics
metrics = ['accuracy', keras.metrics.AUC(), keras.metrics.Recall()]

# %% [markdown]
# ## Experiment 1

# %% [markdown]
# For the first experiment with the ResNet50 V2, we tried adding batchnormalization and Dropout layers

# %%
# Making Resnet Model
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)
resnet50_url = 'https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/5'
feature_extractor_layer = hub.KerasLayer(resnet50_url,
                                           trainable=False, # freeze the underlying patterns
                                           name='feature_extraction_layer',
                                           input_shape=IMAGE_INPUT+(3,)) # define the input image shap

resnet_model = keras.Sequential([
    feature_extractor_layer,
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(1, activation = 'sigmoid'),
])


resnet_model.compile(loss='binary_crossentropy',
                    metrics = [metrics],
                    optimizer = keras.optimizers.Adam(learning_rate = 5e-4))

# %%
resnet_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature_extraction_layer (Ke (None, 2048)              23564800
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 23,575,041
# Trainable params: 6,145
# Non-trainable params: 23,568,896
# _________________________________________________________________

# %%
resnet_history = resnet_model.fit(train_aug,
                                 validation_data = valid,
                                 steps_per_epoch =len(train_aug),
                                 validation_steps =  len(valid),
                                 epochs = 30,
                                 callbacks = [callbacks])
# Out:
# Epoch 1/30
# 16/16 [==============================] - 80s 5s/step - loss: 0.7858 - accuracy: 0.5720 - auc: 0.7406 - recall: 0.6680 - val_loss: 0.6442 - val_accuracy: 0.6172 - val_auc: 0.6581 - val_recall: 0.6667
# val / train : 0.87
# Epoch 2/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.6567 - accuracy: 0.6390 - auc: 0.7113 - recall: 0.6258 - val_loss: 0.5854 - val_accuracy: 0.6797 - val_auc: 0.7613 - val_recall: 0.6349
# val / train : 0.98
# Epoch 3/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.6015 - accuracy: 0.6995 - auc: 0.7591 - recall: 0.7040 - val_loss: 0.5522 - val_accuracy: 0.7109 - val_auc: 0.8050 - val_recall: 0.6349
# val / train : 0.99
# Epoch 4/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.5653 - accuracy: 0.6744 - auc: 0.7765 - recall: 0.6563 - val_loss: 0.5314 - val_accuracy: 0.7266 - val_auc: 0.8332 - val_recall: 0.6032
# val / train : 0.97
# Epoch 5/30
# 16/16 [==============================] - 71s 5s/step - loss: 0.5003 - accuracy: 0.7568 - auc: 0.8375 - recall: 0.7469 - val_loss: 0.5066 - val_accuracy: 0.7578 - val_auc: 0.8552 - val_recall: 0.6349
# val / train : 0.98
# Epoch 6/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.5253 - accuracy: 0.7558 - auc: 0.8296 - recall: 0.7551 - val_loss: 0.4850 - val_accuracy: 0.7734 - val_auc: 0.8667 - val_recall: 0.6508
# val / train : 0.96
# Epoch 7/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.4521 - accuracy: 0.7950 - auc: 0.8711 - recall: 0.7643 - val_loss: 0.4726 - val_accuracy: 0.7656 - val_auc: 0.8698 - val_recall: 0.6984
# val / train : 0.97
# Epoch 8/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.4356 - accuracy: 0.7952 - auc: 0.8810 - recall: 0.7919 - val_loss: 0.4590 - val_accuracy: 0.7812 - val_auc: 0.8812 - val_recall: 0.6984
# val / train : 1.04
# Epoch 9/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.4432 - accuracy: 0.8025 - auc: 0.8770 - recall: 0.7722 - val_loss: 0.4408 - val_accuracy: 0.7969 - val_auc: 0.8937 - val_recall: 0.7302
# val / train : 0.96
# Epoch 10/30
# 16/16 [==============================] - 73s 5s/step - loss: 0.4420 - accuracy: 0.8235 - auc: 0.8826 - recall: 0.7965 - val_loss: 0.4274 - val_accuracy: 0.8281 - val_auc: 0.9015 - val_recall: 0.7937
# val / train : 0.99
# Epoch 11/30
# 16/16 [==============================] - 71s 4s/step - loss: 0.4291 - accuracy: 0.8032 - auc: 0.8826 - recall: 0.7431 - val_loss: 0.4154 - val_accuracy: 0.8516 - val_auc: 0.9071 - val_recall: 0.8413
# val / train : 1.02
# Epoch 12/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3935 - accuracy: 0.8480 - auc: 0.9078 - recall: 0.8571 - val_loss: 0.4023 - val_accuracy: 0.8672 - val_auc: 0.9126 - val_recall: 0.8730
# val / train : 0.98
# Epoch 13/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3827 - accuracy: 0.8097 - auc: 0.9098 - recall: 0.8280 - val_loss: 0.4041 - val_accuracy: 0.8516 - val_auc: 0.9037 - val_recall: 0.8571
# val / train : 0.93
# Epoch 14/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.4018 - accuracy: 0.8348 - auc: 0.9019 - recall: 0.8007 - val_loss: 0.3961 - val_accuracy: 0.8594 - val_auc: 0.9082 - val_recall: 0.8889
# val / train : 0.98
# Epoch 15/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3901 - accuracy: 0.8291 - auc: 0.9081 - recall: 0.8463 - val_loss: 0.3886 - val_accuracy: 0.8594 - val_auc: 0.9121 - val_recall: 0.8889
# val / train : 0.95
# Epoch 16/30
# 16/16 [==============================] - 73s 5s/step - loss: 0.4122 - accuracy: 0.8046 - auc: 0.8932 - recall: 0.7668 - val_loss: 0.3843 - val_accuracy: 0.8594 - val_auc: 0.9123 - val_recall: 0.8889
# val / train : 0.97
# Epoch 17/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3600 - accuracy: 0.8453 - auc: 0.9216 - recall: 0.8168 - val_loss: 0.3739 - val_accuracy: 0.8516 - val_auc: 0.9156 - val_recall: 0.8730
# val / train : 0.95
# Epoch 18/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3883 - accuracy: 0.8195 - auc: 0.9112 - recall: 0.7812 - val_loss: 0.3604 - val_accuracy: 0.8516 - val_auc: 0.9265 - val_recall: 0.8730
# val / train : 0.97
# Epoch 19/30
# 16/16 [==============================] - 71s 5s/step - loss: 0.3416 - accuracy: 0.8565 - auc: 0.9283 - recall: 0.8692 - val_loss: 0.3607 - val_accuracy: 0.8516 - val_auc: 0.9220 - val_recall: 0.8730
# val / train : 1.01
# Epoch 20/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3600 - accuracy: 0.8432 - auc: 0.9195 - recall: 0.8132 - val_loss: 0.3516 - val_accuracy: 0.8516 - val_auc: 0.9288 - val_recall: 0.8730
# val / train : 0.94
# Epoch 21/30
# 16/16 [==============================] - 73s 5s/step - loss: 0.3901 - accuracy: 0.8325 - auc: 0.9015 - recall: 0.8156 - val_loss: 0.3500 - val_accuracy: 0.8516 - val_auc: 0.9288 - val_recall: 0.8730
# val / train : 0.94
# Epoch 22/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3885 - accuracy: 0.8357 - auc: 0.9088 - recall: 0.8185 - val_loss: 0.3490 - val_accuracy: 0.8516 - val_auc: 0.9294 - val_recall: 0.8730
# val / train : 0.91
# Epoch 23/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3840 - accuracy: 0.8217 - auc: 0.9107 - recall: 0.7949 - val_loss: 0.3435 - val_accuracy: 0.8594 - val_auc: 0.9319 - val_recall: 0.8730
# val / train : 0.96
# Epoch 24/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3377 - accuracy: 0.8546 - auc: 0.9288 - recall: 0.8464 - val_loss: 0.3463 - val_accuracy: 0.8594 - val_auc: 0.9299 - val_recall: 0.8889
# val / train : 0.93
# Epoch 25/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3436 - accuracy: 0.8442 - auc: 0.9296 - recall: 0.8324 - val_loss: 0.3522 - val_accuracy: 0.8594 - val_auc: 0.9247 - val_recall: 0.8889
# val / train : 1.05
# Epoch 26/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3380 - accuracy: 0.8708 - auc: 0.9310 - recall: 0.8559 - val_loss: 0.3454 - val_accuracy: 0.8516 - val_auc: 0.9289 - val_recall: 0.8730
# val / train : 1.02
# Epoch 27/30
# 16/16 [==============================] - 71s 4s/step - loss: 0.3470 - accuracy: 0.8588 - auc: 0.9290 - recall: 0.8273 - val_loss: 0.3434 - val_accuracy: 0.8594 - val_auc: 0.9282 - val_recall: 0.8889
# val / train : 0.95
# Epoch 28/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3643 - accuracy: 0.8290 - auc: 0.9096 - recall: 0.7825 - val_loss: 0.3430 - val_accuracy: 0.8594 - val_auc: 0.9283 - val_recall: 0.8730
# val / train : 1.02
# Epoch 29/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3467 - accuracy: 0.8420 - auc: 0.9295 - recall: 0.8673 - val_loss: 0.3330 - val_accuracy: 0.8594 - val_auc: 0.9321 - val_recall: 0.8889
# val / train : 0.91
# Epoch 30/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3245 - accuracy: 0.8601 - auc: 0.9384 - recall: 0.8740 - val_loss: 0.3322 - val_accuracy: 0.8594 - val_auc: 0.9317 - val_recall: 0.8889
# val / train : 0.94

# %%
plot_training_hist(resnet_history)

# %% [markdown]
# The model seems to have improved, and we will move on to the next experiment

# %% [markdown]
# ## Experiment 2

# %% [markdown]
# The previous one is really a good model, compared without any batchnormalization and dropout. We will try to add more dense layers and change the activation function of the layers and see how it affects the performance of the model

# %%
# Making Resnet Model
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)
resnet50_url = 'https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/5'
feature_extractor_layer = hub.KerasLayer(resnet50_url,
                                           trainable=False, # freeze the underlying patterns
                                           name='feature_extraction_layer',
                                           input_shape=IMAGE_INPUT+(3,)) # define the input image shap

resnet_model2 = keras.Sequential([
    feature_extractor_layer,
    keras.layers.BatchNormalization(),
    keras.layers.Dense(80, activation = 'elu', kernel_initializer = 'he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(80, activation = 'elu', kernel_initializer = 'he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(1, activation = 'sigmoid'),
])

resnet_model2.compile(loss='binary_crossentropy',
                    metrics = [metrics],
                    optimizer = keras.optimizers.Adam(learning_rate = 5e-4))

# %%
resnet_model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# feature_extraction_layer (Ke (None, 2048)              23564800
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# dense (Dense)                (None, 80)                163920
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 80)                320
# _________________________________________________________________
# dropout (Dropout)            (None, 80)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 80)                6480
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 80)                320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 80)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 81
# =================================================================
# Total params: 23,744,113
# Trainable params: 174,897
# Non-trainable params: 23,569,216
# _________________________________________________________________

# %%
feature_extractor_layer.output_shape
# Out:
# (None, 2048)

# %%
resnet_history2 = resnet_model2.fit(train_aug,
                                 validation_data = valid,
                                steps_per_epoch = len(train_aug),
                                 validation_steps =  len(valid),
                                 epochs = 30,
                                 callbacks = [callbacks])
# Out:
# Epoch 1/30
# 16/16 [==============================] - 79s 5s/step - loss: 0.8593 - accuracy: 0.5736 - auc: 0.7468 - recall: 0.6973 - val_loss: 0.5011 - val_accuracy: 0.7578 - val_auc: 0.8436 - val_recall: 0.8413
# val / train : 0.66
# Epoch 2/30
# 16/16 [==============================] - 74s 5s/step - loss: 0.6136 - accuracy: 0.7274 - auc: 0.7873 - recall: 0.6996 - val_loss: 0.4294 - val_accuracy: 0.8281 - val_auc: 0.8921 - val_recall: 0.7778
# val / train : 0.75
# Epoch 3/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.5307 - accuracy: 0.7630 - auc: 0.8409 - recall: 0.7654 - val_loss: 0.4461 - val_accuracy: 0.8125 - val_auc: 0.9089 - val_recall: 0.6349
# val / train : 0.85
# Epoch 4/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.4363 - accuracy: 0.8237 - auc: 0.8850 - recall: 0.7917 - val_loss: 0.3876 - val_accuracy: 0.8594 - val_auc: 0.9150 - val_recall: 0.7778
# val / train : 0.90
# Epoch 5/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3970 - accuracy: 0.8224 - auc: 0.9007 - recall: 0.7900 - val_loss: 0.3630 - val_accuracy: 0.8828 - val_auc: 0.9172 - val_recall: 0.8413
# val / train : 0.83
# Epoch 6/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3761 - accuracy: 0.8424 - auc: 0.9112 - recall: 0.8022 - val_loss: 0.3799 - val_accuracy: 0.8516 - val_auc: 0.9079 - val_recall: 0.8095
# val / train : 0.97
# Epoch 7/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3959 - accuracy: 0.8326 - auc: 0.9052 - recall: 0.8330 - val_loss: 0.3738 - val_accuracy: 0.8594 - val_auc: 0.9088 - val_recall: 0.8095
# val / train : 0.88
# Epoch 8/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3408 - accuracy: 0.8168 - auc: 0.9259 - recall: 0.8072 - val_loss: 0.3600 - val_accuracy: 0.8828 - val_auc: 0.9160 - val_recall: 0.8571
# val / train : 1.00
# Epoch 9/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3235 - accuracy: 0.8653 - auc: 0.9383 - recall: 0.8809 - val_loss: 0.3841 - val_accuracy: 0.8516 - val_auc: 0.9057 - val_recall: 0.8254
# val / train : 1.17
# Epoch 10/30
# 16/16 [==============================] - 73s 5s/step - loss: 0.3158 - accuracy: 0.8648 - auc: 0.9390 - recall: 0.8735 - val_loss: 0.3651 - val_accuracy: 0.8516 - val_auc: 0.9125 - val_recall: 0.8254
# val / train : 1.03
# Epoch 11/30
# 16/16 [==============================] - 73s 5s/step - loss: 0.3660 - accuracy: 0.8217 - auc: 0.9207 - recall: 0.8352 - val_loss: 0.3670 - val_accuracy: 0.8594 - val_auc: 0.9123 - val_recall: 0.8254
# val / train : 1.07
# Epoch 12/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3556 - accuracy: 0.8488 - auc: 0.9245 - recall: 0.8478 - val_loss: 0.3627 - val_accuracy: 0.8438 - val_auc: 0.9145 - val_recall: 0.8571
# val / train : 1.09
# Epoch 13/30
# 16/16 [==============================] - 73s 5s/step - loss: 0.2482 - accuracy: 0.9098 - auc: 0.9627 - recall: 0.8995 - val_loss: 0.3576 - val_accuracy: 0.8516 - val_auc: 0.9189 - val_recall: 0.8730
# val / train : 1.27
# Epoch 14/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.3655 - accuracy: 0.8322 - auc: 0.9240 - recall: 0.8534 - val_loss: 0.3794 - val_accuracy: 0.8281 - val_auc: 0.9083 - val_recall: 0.8571
# val / train : 1.08
# Epoch 15/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.2890 - accuracy: 0.8819 - auc: 0.9474 - recall: 0.8876 - val_loss: 0.3607 - val_accuracy: 0.8594 - val_auc: 0.9151 - val_recall: 0.8730
# val / train : 1.32
# Epoch 16/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.2885 - accuracy: 0.8822 - auc: 0.9493 - recall: 0.8730 - val_loss: 0.3560 - val_accuracy: 0.8594 - val_auc: 0.9151 - val_recall: 0.8730
# val / train : 1.23
# Epoch 17/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.2766 - accuracy: 0.8949 - auc: 0.9542 - recall: 0.9108 - val_loss: 0.3870 - val_accuracy: 0.8438 - val_auc: 0.9089 - val_recall: 0.8571
# val / train : 1.34
# Epoch 18/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.2822 - accuracy: 0.8894 - auc: 0.9530 - recall: 0.9153 - val_loss: 0.3716 - val_accuracy: 0.8516 - val_auc: 0.9171 - val_recall: 0.8730
# val / train : 1.30
# Epoch 19/30
# 16/16 [==============================] - 73s 5s/step - loss: 0.2854 - accuracy: 0.8911 - auc: 0.9503 - recall: 0.8803 - val_loss: 0.3530 - val_accuracy: 0.8672 - val_auc: 0.9242 - val_recall: 0.8730
# val / train : 1.31
# Epoch 20/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.2853 - accuracy: 0.8753 - auc: 0.9494 - recall: 0.8730 - val_loss: 0.3834 - val_accuracy: 0.8438 - val_auc: 0.9155 - val_recall: 0.8571
# val / train : 1.45
# Epoch 21/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.2558 - accuracy: 0.8937 - auc: 0.9623 - recall: 0.8667 - val_loss: 0.3618 - val_accuracy: 0.8594 - val_auc: 0.9215 - val_recall: 0.8730
# val / train : 1.51
# Epoch 22/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.2288 - accuracy: 0.9056 - auc: 0.9695 - recall: 0.8915 - val_loss: 0.3916 - val_accuracy: 0.8516 - val_auc: 0.9095 - val_recall: 0.8413
# val / train : 1.72
# Epoch 23/30
# 16/16 [==============================] - 72s 4s/step - loss: 0.2037 - accuracy: 0.9353 - auc: 0.9766 - recall: 0.9289 - val_loss: 0.3835 - val_accuracy: 0.8438 - val_auc: 0.9162 - val_recall: 0.8571
# val / train : 1.66
# Epoch 24/30
# 16/16 [==============================] - 72s 5s/step - loss: 0.2799 - accuracy: 0.8803 - auc: 0.9561 - recall: 0.8777 - val_loss: 0.3802 - val_accuracy: 0.8203 - val_auc: 0.9228 - val_recall: 0.8730
# val / train : 1.56

# %%
plot_training_hist(resnet_history2)

# %% [markdown]
# On the second experiment, the model looks to have improved by a lot! We will use this model architecture for further parameter tuning and evaluation

# %% [markdown]
# # HyperParameter Tuning with HyperBand

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import backend as K
from sklearn.metrics import classification_report
import keras_tuner as kt
import numpy as np

# %% [markdown]
# We will now create a function which return our model. The keras api used for hyperparameter requires a function which return a model for parameter searching

# %%
def model_builder(hp):
    model = keras.Sequential()
    resnet50_url = 'https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/5'
    feature_extractor_layer = hub.KerasLayer(resnet50_url,
                                           trainable=False, # freeze the underlying patterns
                                           name='feature_extraction_layer',
                                           input_shape=IMAGE_INPUT+(3,)) # define the input image shap

    hp_units = hp.Int('units', min_value=80, max_value=160, step=40)
    hp_dropout = hp.Choice('dropoutRate', values=[0.2, 0.3, 0.4])
    hp_activation = hp.Choice('activation', values = ['elu', 'relu'])
    model = keras.Sequential([
    feature_extractor_layer,
    keras.layers.BatchNormalization(),
    keras.layers.Dense(units = hp_units, activation = hp_activation, kernel_initializer = 'he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(hp_dropout),
    keras.layers.Dense(units = hp_units, activation = hp_activation, kernel_initializer = 'he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(hp_dropout),
    keras.layers.Dense(1, activation = 'sigmoid'),
    ])
    
    hp_learning_rate = hp.Choice('learning_rate', values=[5e-3, 5e-4, 5e-5])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss='binary_crossentropy',
                metrics=[metrics])

    return model

# %% [markdown]
# I will be using HyperBand as the tuning algorithm. Hyperband is a relatively new method for tuning iterative algorithms. It performs random sampling and attempts to gain an edge by using time spent optimizing in the best way. It's faster and better than Randomized tuning algorithm.

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=20,
                     factor=3,
                     directory='my_dir',
                     project_name='tuning_model',
                    seed = 19)

# %% [markdown]
# We will focus on val_accuracy, because on the previous hyperparameter tuning, making the objective into val_recall will make the model focus too much on the recall, causing it to be underfitting when it tried to predict unseen data

# %%
#Searching for best parameter
#Using only early_stopping callback(patience = 5)
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

tuner.search(train_aug, validation_data = valid, epochs = 20, callbacks = [stop_early])
# Out:
# Trial 30 Complete [00h 24m 09s]
# val_accuracy: 0.859375
#
# Best val_accuracy So Far: 0.8984375
# Total elapsed time: 04h 38m 48s

# %% [markdown]
# After the searching is finished, we can extract the model parameters and see the compositions

# %%
best_hyperparameters = tuner.get_best_hyperparameters(1)[0]
best_hyperparameters.values
# Out:
# {'units': 160,
#  'dropoutRate': 0.3,
#  'activation': 'elu',
#  'learning_rate': 0.0005,
#  'tuner/epochs': 20,
#  'tuner/initial_epoch': 7,
#  'tuner/bracket': 1,
#  'tuner/round': 1,
#  'tuner/trial_id': '10210de1829bc0c63e3f6bdc532de972'}

# %% [markdown]
# We got the best parameters! Now lets continue to final fitting for evaluation

# %%
# We can also use customized callback, where we customize them on our own
class PrintValTrainRatioCallback(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs): 
    print("val / train : {:.2f}".format(logs['val_loss']/logs['loss']))
    
#Another Additional callbacks (Checkpoint, Early Stopping)
checkpoint_cb = keras.callbacks.ModelCheckpoint("tuned_model.h5")
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True) 
callbacks = [checkpoint_cb, early_stopping_cb, PrintValTrainRatioCallback()]

# %% [markdown]
# We will manually input the parameters gained from the tuner, and create a model for evaluation

# %%
# Making Resnet Model
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)
resnet50_url = 'https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/5'
feature_extractor_layer = hub.KerasLayer(resnet50_url,
                                           trainable=False, # freeze the underlying patterns
                                           name='feature_extraction_layer',
                                           input_shape=IMAGE_INPUT+(3,)) # define the input image shap

resnet_model3 = keras.Sequential([
    feature_extractor_layer,
    keras.layers.BatchNormalization(),
    keras.layers.Dense(160, activation = 'elu', kernel_initializer = 'he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(160, activation = 'elu', kernel_initializer = 'he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(1, activation = 'sigmoid'),
])

resnet_model3.compile(loss='binary_crossentropy',
                    metrics = [metrics],
                    optimizer = keras.optimizers.Adam(learning_rate = 5e-4))

# %%
resnet_history3 = resnet_model3.fit(train_aug,
                 validation_data = valid,
                 steps_per_epoch = len(train),
                validation_steps = len(valid),
                  epochs = 20,
        callbacks = [callbacks])
# Out:
# Epoch 1/20
# 16/16 [==============================] - 82s 5s/step - loss: 0.8563 - accuracy: 0.5491 - auc: 0.7354 - recall: 0.6234 - val_loss: 0.7898 - val_accuracy: 0.6406 - val_auc: 0.8726 - val_recall: 0.2698
# val / train : 1.04
# Epoch 2/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4920 - accuracy: 0.7816 - auc: 0.8584 - recall: 0.7790 - val_loss: 0.7850 - val_accuracy: 0.6797 - val_auc: 0.8939 - val_recall: 0.3492
# val / train : 1.43
# Epoch 3/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4840 - accuracy: 0.7915 - auc: 0.8710 - recall: 0.7649 - val_loss: 0.5403 - val_accuracy: 0.7656 - val_auc: 0.8957 - val_recall: 0.5238
# val / train : 1.10
# Epoch 4/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4470 - accuracy: 0.8262 - auc: 0.8774 - recall: 0.8079 - val_loss: 0.4083 - val_accuracy: 0.8281 - val_auc: 0.9221 - val_recall: 0.6825
# val / train : 0.89
# Epoch 5/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4050 - accuracy: 0.7871 - auc: 0.8966 - recall: 0.7560 - val_loss: 0.3715 - val_accuracy: 0.8594 - val_auc: 0.9181 - val_recall: 0.8254
# val / train : 0.85
# Epoch 6/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.4052 - accuracy: 0.8234 - auc: 0.9017 - recall: 0.7998 - val_loss: 0.3920 - val_accuracy: 0.8125 - val_auc: 0.9111 - val_recall: 0.7143
# val / train : 1.02
# Epoch 7/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.3493 - accuracy: 0.8317 - auc: 0.9257 - recall: 0.8006 - val_loss: 0.3552 - val_accuracy: 0.8359 - val_auc: 0.9245 - val_recall: 0.7778
# val / train : 0.94
# Epoch 8/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.3554 - accuracy: 0.8547 - auc: 0.9217 - recall: 0.8251 - val_loss: 0.3627 - val_accuracy: 0.8203 - val_auc: 0.9190 - val_recall: 0.8095
# val / train : 1.02
# Epoch 9/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.3042 - accuracy: 0.8740 - auc: 0.9475 - recall: 0.8670 - val_loss: 0.3751 - val_accuracy: 0.8047 - val_auc: 0.9137 - val_recall: 0.8413
# val / train : 1.13
# Epoch 10/20
# 16/16 [==============================] - 71s 5s/step - loss: 0.2898 - accuracy: 0.8662 - auc: 0.9496 - recall: 0.8375 - val_loss: 0.3510 - val_accuracy: 0.8359 - val_auc: 0.9225 - val_recall: 0.8095
# val / train : 1.17
# Epoch 11/20
# 16/16 [==============================] - 72s 4s/step - loss: 0.3812 - accuracy: 0.8582 - auc: 0.9169 - recall: 0.8921 - val_loss: 0.3709 - val_accuracy: 0.7969 - val_auc: 0.9177 - val_recall: 0.8413
# val / train : 1.09
# Epoch 12/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.3036 - accuracy: 0.8620 - auc: 0.9432 - recall: 0.8477 - val_loss: 0.3635 - val_accuracy: 0.8281 - val_auc: 0.9216 - val_recall: 0.8571
# val / train : 1.25
# Epoch 13/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.2431 - accuracy: 0.9063 - auc: 0.9634 - recall: 0.8843 - val_loss: 0.3675 - val_accuracy: 0.8281 - val_auc: 0.9186 - val_recall: 0.8730
# val / train : 1.25
# Epoch 14/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.2638 - accuracy: 0.8899 - auc: 0.9591 - recall: 0.8741 - val_loss: 0.3355 - val_accuracy: 0.8359 - val_auc: 0.9309 - val_recall: 0.8413
# val / train : 1.24
# Epoch 15/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.2719 - accuracy: 0.8855 - auc: 0.9550 - recall: 0.8919 - val_loss: 0.3195 - val_accuracy: 0.8516 - val_auc: 0.9385 - val_recall: 0.8730
# val / train : 1.15
# Epoch 16/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.3026 - accuracy: 0.8737 - auc: 0.9453 - recall: 0.8552 - val_loss: 0.3811 - val_accuracy: 0.8125 - val_auc: 0.9181 - val_recall: 0.8571
# val / train : 1.34
# Epoch 17/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.3042 - accuracy: 0.8773 - auc: 0.9498 - recall: 0.8782 - val_loss: 0.3245 - val_accuracy: 0.8281 - val_auc: 0.9357 - val_recall: 0.8571
# val / train : 1.22
# Epoch 18/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.2088 - accuracy: 0.9162 - auc: 0.9743 - recall: 0.9324 - val_loss: 0.3418 - val_accuracy: 0.8438 - val_auc: 0.9366 - val_recall: 0.8889
# val / train : 1.35
# Epoch 19/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.2304 - accuracy: 0.8955 - auc: 0.9687 - recall: 0.8948 - val_loss: 0.3606 - val_accuracy: 0.8203 - val_auc: 0.9289 - val_recall: 0.8571
# val / train : 1.44
# Epoch 20/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.1966 - accuracy: 0.9106 - auc: 0.9781 - recall: 0.8844 - val_loss: 0.3534 - val_accuracy: 0.8438 - val_auc: 0.9278 - val_recall: 0.8413
# val / train : 1.79

# %%
plot_training_hist(resnet_history3)

# %% [markdown]
# # Evaluation on Unseen Data

# %%
# Get label
y_real = test_df['Label']

# %%
#Change the datatype to int
y_real = y_real.astype('int')

# %%
loss, acc, auc, recall = resnet_model3.evaluate(test)
# Out:
# 5/5 [==============================] - 15s 3s/step - loss: 0.4437 - accuracy: 0.8313 - auc: 0.8867 - recall: 0.8101

# %%
def predictUnseenValues(model, test):
    pred = model.predict(test)
    a =[]
    for i in pred:
        if i > 0.5:
            a.append(int(1))
        else:
            a.append(int(0))
    print("Accuracy score : ", accuracy_score(y_real, a))
    print("Recall score : ", recall_score(y_real, a, average = 'weighted'))
    return a

# %%
final_pred= predictUnseenValues(resnet_model3,test)
# Out:
# Accuracy score :  0.83125
# Recall score :  0.83125

# %%
print(classification_report(y_real, final_pred, labels=[0,1], zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84        81
#            1       0.84      0.81      0.83        79
#
#     accuracy                           0.83       160
#    macro avg       0.83      0.83      0.83       160
# weighted avg       0.83      0.83      0.83       160

# %%
a = confusion_matrix(y_real, final_pred)
a
# Out:
# array([[69, 12],
#        [15, 64]])

# %% [markdown]
# - True Positive = 69
# - False Negative = 15
# - True Negative = 64
# - False Positive = 12
